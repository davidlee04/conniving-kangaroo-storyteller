# %% [markdown]
# # Team: Conniving Kangaroo
# ## System: ClueLLM
#
# Story generation system using Template 1: Suspense Generation

# %% [markdown]
# ### Technical Details:
# - Utilizes Google's Gemini 2.5 Flash
# - Please use your own API key (see README)
# - Typical run time for all cells in this notebook: ~5-10 minutes
# - Typical cost for API calls: ~15 cents

# %%
# !pip install -q -U google-genai
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## LLM Setup
#
# Define Gemini model API and LLM helper methods.

# %%
import os
# replace with your own API key
os.environ["GOOGLE_API_KEY"] = ""

# %%
from google import genai

client = genai.Client()
MODEL = "gemini-2.5-flash"

# Sanity check
response = client.models.generate_content(model=MODEL, contents="Say: ready")
print("LLM status:", response.text.strip())
# Out:
# LLM status: Ready

# %%
def ask_llm(prompt: str):
    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )
    return response.text.strip()

# %%
def extract_json(text: str):
    """
    Extract the first JSON object or array from model output.
    Handles markdown code fences like ```json ... ```.
    """
    # Remove markdown fences if present
    fenced = re.search(r"```(?:json)?\s*(.*?)```", text, re.DOTALL)
    if fenced:
        text = fenced.group(1).strip()

    # Try full parse first
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        pass

    # Fallback: find first JSON object or array
    match = re.search(r"(\{.*\}|\[.*\])", text, re.DOTALL)
    if match:
        return json.loads(match.group(1))

    raise ValueError(f"No JSON found in LLM response:\n{text}")

# %% [markdown]
# ## Data Structures
# Defines all dataclasses used to store story state. Sections 2 and 3 (story generation and compilation) will populate these.

# %% [markdown]
# | Class | Role | Function |
# |---|---|---|
# | `CrimeDetails` | The hidden truth | Keeps the ground-truth crime facts isolated so the LLM can never accidentally leak them into suspect dialogue or clue descriptions |
# | `Character` | Any person in the story | Stores means/motive/opportunity explicitly so the meta-controller can check MMO coverage without re-querying the LLM |
# | `Clue` | A piece of evidence | `is_red_herring` and `discovered` flags let the controller track what the detective *can* know vs. what *really* points to the criminal |
# | `PlotPoint` | One story beat | `suspense_score` on each beat makes the rising tension arc a measurable, enforceable property rather than a vague stylistic goal |
# | `StoryWorld` | Global state container | A single object passed by reference into every generation function — any LLM call can read current state via `summary_so_far()` without duplicating data |

# %%
import json
import re
from dataclasses import dataclass, field
from typing import List, Optional
from pprint import pprint


@dataclass
class Character:
    """A character in the story: detective, suspect, criminal, or witness."""
    name: str
    role: str                        # 'detective' | 'suspect' | 'criminal' | 'witness'
    description: str
    means: str                       # capability to commit the crime
    motive: str                      # reason to commit the crime
    opportunity: str                 # could they have been at the scene?
    alibi: str
    alibi_is_lie: bool = False
    is_criminal: bool = False
    eliminated: bool = False         # True once the detective rules them out
    notes: List[str] = field(default_factory=list)


@dataclass
class Clue:
    """A piece of evidence or information discoverable by the detective."""
    clue_id: int
    description: str
    location: str
    discovered: bool = False
    is_red_herring: bool = False
    points_to: str = ""              # character or event this implicates
    revealed_in_plot_point: int = -1


@dataclass
class PlotPoint:
    """One story beat that advances the plot."""
    index: int
    title: str
    description: str
    action_taken: str
    outcome: str
    obstacle: str
    suspense_score: float            # 0.0 (low tension) → 1.0 (maximum)
    characters_involved: List[str] = field(default_factory=list)
    clues_revealed: List[int] = field(default_factory=list)
    clues_used: List[int] = field(default_factory=list)


@dataclass
class CrimeDetails:
    """The hidden backstory: what really happened before the detective arrives."""
    crime_type: str
    victim: str
    location: str
    time_of_crime: str
    method: str
    criminal_name: str
    criminal_motive: str
    criminal_means: str
    key_evidence_hidden: List[str] = field(default_factory=list)
    backstory_summary: str = ""


@dataclass
class StoryWorld:
    """Master container for all story state."""
    crime_details: Optional[CrimeDetails] = None
    characters: List[Character] = field(default_factory=list)
    clues: List[Clue] = field(default_factory=list)
    plot_points: List[PlotPoint] = field(default_factory=list)
    countdown_deadline: str = ""
    countdown_consequence: str = ""
    final_narrative: str = ""

    def get_character(self, name: str) -> Optional[Character]:
        for c in self.characters:
            if c.name.lower() == name.lower():
                return c
        return None

    def get_clue(self, clue_id: int) -> Optional[Clue]:
        for cl in self.clues:
            if cl.clue_id == clue_id:
                return cl
        return None

    def discovered_clues(self) -> List[Clue]:
        return [cl for cl in self.clues if cl.discovered]

    def active_suspects(self) -> List[Character]:
        return [c for c in self.characters if c.role in ('suspect', 'criminal') and not c.eliminated]

    def summary_so_far(self) -> str:
        """Brief text digest of current story state, used as context in LLM prompts."""
        lines = []
        if self.crime_details:
            cd = self.crime_details
            lines.append(f"CRIME: {cd.crime_type} of {cd.victim} at {cd.location} ({cd.time_of_crime}).")
        lines.append(f"ACTIVE SUSPECTS: {[c.name for c in self.active_suspects()]}")
        lines.append(f"CLUES FOUND: {[cl.description[:40] for cl in self.discovered_clues()]}")
        if self.plot_points:
            last = self.plot_points[-1]
            lines.append(f"LAST PLOT POINT ({last.index}): {last.title} — {last.outcome}")
        return "\n".join(lines)


print("Data structures defined.")
# Out:
# Data structures defined.

# %%
# Initialize StoryWorld object
world = StoryWorld()
print("StoryWorld initialized:", world)
# Out:
# StoryWorld initialized: StoryWorld(crime_details=None, characters=[], clues=[], plot_points=[], countdown_deadline='', countdown_consequence='', final_narrative='')

# %% [markdown]
# ## Phase 1: Crime Backstory

# %%
# Builds the prompt for the LLM to generate the crime details
def build_crime_details_prompt() -> str:
    return """
You are helping build the hidden ground-truth backstory for a gala murder crime mystery.

Generate a single crime scenario for a detective story.

Requirements:
- The crime must be a serious crime suitable for a mystery story.
- It must be solvable, but not obvious.
- The crime must support multiple plausible suspects later.
- The criminal's motive, means, and opportunity must all make sense together.
- The method of the crime must leave behind evidence that can later be discovered.
- The crime should not rely on supernatural elements or impossible coincidences.

Return ONLY valid JSON with exactly these keys:
{
  "crime_type": "...",
  "victim": "...",
  "location": "...",
  "time_of_crime": "...",
  "method": "...",
  "criminal_name": "...",
  "criminal_motive": "...",
  "criminal_means": "...",
  "key_evidence_hidden": ["...", "...", "..."],
  "backstory_summary": "..."
}

Field guidance:
- crime_type: e.g. "murder", "blackmail", "kidnapping", "art theft" (in this case, it will be "murder")
- victim: full name and a few identifying words
- location: specific and story-friendly
- time_of_crime: specific enough to anchor a timeline
- method: how the crime was carried out
- criminal_name: full name
- criminal_motive: concrete and personal
- criminal_means: how they were capable of doing it
- key_evidence_hidden: 3 to 5 important hidden evidence items
- backstory_summary: 1 paragraph summary of what truly happened before the detective starts investigating

Important:
- The criminal should not be the most obvious suspect.
- The motive should be meaningful, not generic.
- The evidence should connect naturally to the crime method.
- Return JSON only. No explanation.
""".strip()


# Prompts the LLM and extracts the answer to a data structure
def generate_crime_details() -> CrimeDetails:
    prompt = build_crime_details_prompt()
    raw = ask_llm(prompt)
    data = extract_json(raw)

    crime = CrimeDetails(
        crime_type=data["crime_type"],
        victim=data["victim"],
        location=data["location"],
        time_of_crime=data["time_of_crime"],
        method=data["method"],
        criminal_name=data["criminal_name"],
        criminal_motive=data["criminal_motive"],
        criminal_means=data["criminal_means"],
        key_evidence_hidden=data.get("key_evidence_hidden", []),
        backstory_summary=data.get("backstory_summary", "")
    )
    return crime

# %%
# Run crime detail generation
world.crime_details = generate_crime_details()

pprint(world.crime_details)
print()
print(world.crime_details.backstory_summary)
# Out:
# CrimeDetails(crime_type='murder',
#              victim='Elias Thorne, CEO of Thorne Industries and renowned '
#                     'philanthropist, age 62.',
#              location='The opulent private study on the third floor of '
#                       'Blackwood Manor, where the annual Thorne Charity Gala '
#                       'was being held.',
#              time_of_crime='Between 9:45 PM and 10:15 PM, during the main '
#                            'auction event.',
#              method='Dr. Evelyn Reed administered a fast-acting neurotoxin to '
#                     'Elias Thorne using a specially modified hatpin with a '
#                     'concealed hypodermic needle. She subtly pricked him '
#                     'during a close conversation in a secluded hallway near '
#                     'the study. Thorne, feeling suddenly unwell, excused '
#                     'himself to his study where he quickly succumbed to the '
#                     'toxin, making it appear as a natural heart attack or '
#                     'collapse.',
#              criminal_name="Dr. Evelyn Reed, Elias Thorne's personal physician "
#                            'and long-time confidante.',
#              criminal_motive='Elias Thorne had been relentlessly blackmailing '
#                              'Dr. Reed for over a year, threatening to expose '
#                              'a devastating secret about her past professional '
#                              'misconduct – a severe misdiagnosis and '
#                              "subsequent cover-up that led to a patient's "
#                              'death – which would ruin her career and lead to '
#                              'criminal charges. Thorne was escalating his '
#                              'demands, planning to make a public accusation at '
#                              'the gala, leaving Evelyn no perceived '
#                              'alternative.',
#              criminal_means="As Thorne's personal physician, Dr. Reed had "
#                             'intimate knowledge of his health vulnerabilities, '
#                             'access to specialized medical equipment, and the '
#                             'expertise to discreetly acquire and administer a '
#                             'rare, fast-acting neurotoxin that would mimic '
#                             'natural causes. Her trusted position also allowed '
#                             'her close, private access to Thorne throughout '
#                             'the evening.',
#              key_evidence_hidden=['A faint, almost invisible puncture mark on '
#                                   "Elias Thorne's neck, initially overlooked "
#                                   'by first responders and paramedics.',
#                                   'A decorative hatpin, missing its sharp tip, '
#                                   'found tucked away behind a loose floorboard '
#                                   'in the private study, with trace amounts of '
#                                   "the neurotoxin and Thorne's DNA.",
#                                   'A discarded prescription label for a '
#                                   'powerful sedative, dated for the day of the '
#                                   "gala, in Thorne's coat pocket, written by "
#                                   'Dr. Reed, with an unusually high and '
#                                   'unrecorded dosage.',
#                                   'A heavily encrypted, partially recovered '
#                                   "entry from Elias Thorne's private digital "
#                                   'diary, found on his tablet in the study, '
#                                   "referencing 'E.R.'s final payment' and 'the "
#                                   "gala's grand reveal' in a threatening tone.",
#                                   'A specific, microscopic synthetic fiber '
#                                   "from Dr. Reed's formal gown, found caught "
#                                   "on the lapel of Elias Thorne's tuxedo "
#                                   'jacket.'],
#              backstory_summary='Elias Thorne had been relentlessly '
#                                'blackmailing his personal physician, Dr. '
#                                'Evelyn Reed, threatening to expose a '
#                                'career-ending secret at his annual charity '
#                                'gala. Cornered and desperate, Evelyn saw no '
#                                'other escape. During the gala, she subtly '
#                                'administered a fast-acting neurotoxin to '
#                                'Thorne using a modified hatpin during a '
#                                'private conversation. Feeling unwell, Thorne '
#                                'retreated to his private study where he '
#                                'quickly succumbed. Evelyn then discreetly '
#                                'disposed of the hatpin and attempted to mask '
#                                'the true cause of death by previously '
#                                'prescribing a sedative to Thorne, aiming to '
#                                'make his death appear as a natural heart '
#                                "attack exacerbated by the gala's excitement.")
#
# Elias Thorne had been relentlessly blackmailing his personal physician, Dr. Evelyn Reed, threatening to expose a career-ending secret at his annual charity gala. Cornered and desperate, Evelyn saw no other escape. During the gala, she subtly administered a fast-acting neurotoxin to Thorne using a modified hatpin during a private conversation. Feeling unwell, Thorne retreated to his private study where he quickly succumbed. Evelyn then discreetly disposed of the hatpin and attempted to mask the true cause of death by previously prescribing a sedative to Thorne, aiming to make his death appear as a natural heart attack exacerbated by the gala's excitement.

# %% [markdown]
# ## Phase 2: Characters & Clues

# %%
# Builds the prompt for generating character list
def build_characters_prompt(crime: CrimeDetails) -> str:
    crime_payload = {
        "crime_type": crime.crime_type,
        "victim": crime.victim,
        "location": crime.location,
        "time_of_crime": crime.time_of_crime,
        "method": crime.method,
        "criminal_name": crime.criminal_name,
        "criminal_motive": crime.criminal_motive,
        "criminal_means": crime.criminal_means,
        "key_evidence_hidden": crime.key_evidence_hidden,
        "backstory_summary": crime.backstory_summary,
    }

    return f"""
You are generating the cast of characters for a crime mystery.

The hidden ground-truth crime is:
{json.dumps(crime_payload, indent=2)}

Create:
- 1 detective
- 5 suspects who are NOT the criminal
- 1 criminal character whose name MUST exactly match the criminal_name above

Return ONLY valid JSON with exactly this structure:
{{
  "detective": {{
    "name": "...",
    "role": "detective",
    "description": "...",
    "means": "N/A",
    "motive": "solve the case",
    "opportunity": "arrives after the crime to investigate",
    "alibi": "N/A"
  }},
  "criminal": {{
    "name": "...",
    "role": "criminal",
    "description": "...",
    "means": "...",
    "motive": "...",
    "opportunity": "...",
    "alibi": "...",
    "alibi_is_lie": true
  }},
  "suspects": [
    {{
      "name": "...",
      "role": "suspect",
      "description": "...",
      "means": "...",
      "motive": "...",
      "opportunity": "...",
      "alibi": "...",
      "alibi_is_lie": false
    }}
  ]
}}

Requirements:
- The criminal name must exactly match the given criminal_name.
- There must be exactly 5 suspects in the suspects list.
- Every suspect must have plausible means, motive, and opportunity.
- At least 2 suspects should look strongly suspicious at first.
- At least 2 innocent suspects should have a false or misleading alibi.
- The criminal should not be the most obvious suspect.
- The detective should feel capable and specific, not generic.
- Suspects should have relationships to the victim, location, or circumstances of the crime.
- Keep all details realistic and internally consistent.

Return JSON only.
""".strip()


# Prompts the LLM and extracts the character data to our data structure
def generate_characters(world: StoryWorld) -> List[Character]:
    if not world.crime_details:
        raise ValueError("world.crime_details must exist before generating characters.")

    raw = ask_llm(build_characters_prompt(world.crime_details))
    data = extract_json(raw)

    characters = []

    detective_data = data["detective"]
    detective = Character(
        name=detective_data["name"],
        role="detective",
        description=detective_data["description"],
        means=detective_data.get("means", "N/A"),
        motive=detective_data.get("motive", "solve the case"),
        opportunity=detective_data.get("opportunity", "arrives after the crime to investigate"),
        alibi=detective_data.get("alibi", "N/A"),
        alibi_is_lie=False,
        is_criminal=False,
        eliminated=False,
        notes=[]
    )
    characters.append(detective)

    criminal_data = data["criminal"]
    criminal = Character(
        name=criminal_data["name"],
        role="criminal",
        description=criminal_data["description"],
        means=criminal_data["means"],
        motive=criminal_data["motive"],
        opportunity=criminal_data["opportunity"],
        alibi=criminal_data["alibi"],
        alibi_is_lie=criminal_data.get("alibi_is_lie", True),
        is_criminal=True,
        eliminated=False,
        notes=[]
    )
    characters.append(criminal)

    for suspect_data in data["suspects"]:
        suspect = Character(
            name=suspect_data["name"],
            role="suspect",
            description=suspect_data["description"],
            means=suspect_data["means"],
            motive=suspect_data["motive"],
            opportunity=suspect_data["opportunity"],
            alibi=suspect_data["alibi"],
            alibi_is_lie=suspect_data.get("alibi_is_lie", False),
            is_criminal=False,
            eliminated=False,
            notes=[]
        )
        characters.append(suspect)

    return characters


# Builds the prompt for the LLM to validate our character list  
def build_character_validation_prompt(world: StoryWorld, characters: List[Character]) -> str:
    crime = world.crime_details
    if not crime:
        raise ValueError("No crime details in world.")

    payload = {
        "crime_details": {
            "crime_type": crime.crime_type,
            "victim": crime.victim,
            "location": crime.location,
            "time_of_crime": crime.time_of_crime,
            "method": crime.method,
            "criminal_name": crime.criminal_name,
            "criminal_motive": crime.criminal_motive,
            "criminal_means": crime.criminal_means,
            "backstory_summary": crime.backstory_summary,
        },
        "characters": [
            {
                "name": c.name,
                "role": c.role,
                "description": c.description,
                "means": c.means,
                "motive": c.motive,
                "opportunity": c.opportunity,
                "alibi": c.alibi,
                "alibi_is_lie": c.alibi_is_lie,
                "is_criminal": c.is_criminal,
            }
            for c in characters
        ]
    }

    return f"""
You are validating the character set for a crime mystery.

Data:
{json.dumps(payload, indent=2)}

Check:
1. Is there exactly 1 detective?
2. Is there exactly 1 criminal and does their name match the hidden criminal_name?
3. Are there exactly 5 non-criminal suspects?
4. Does every suspect have plausible means, motive, or opportunity?
5. Are at least 2 suspects genuinely suspicious at first?
6. Are the characters distinct from one another?
7. Are there any contradictions with the crime setup?

Return ONLY valid JSON:
{{
  "is_valid": true,
  "issues": ["..."],
  "suggested_fixes": ["..."]
}}
""".strip()


# Prompts the LLM to validate our character list
def validate_characters(world: StoryWorld, characters: List[Character]) -> dict:
    raw = ask_llm(build_character_validation_prompt(world, characters))
    return extract_json(raw)

# %%
# Builds the prompt for generating clues
def build_clues_prompt(world: StoryWorld) -> str:
    if not world.crime_details:
        raise ValueError("world.crime_details must exist before generating clues.")
    if not world.characters:
        raise ValueError("world.characters must exist before generating clues.")

    crime = world.crime_details
    character_payload = [
        {
            "name": c.name,
            "role": c.role,
            "description": c.description,
            "means": c.means,
            "motive": c.motive,
            "opportunity": c.opportunity,
            "alibi": c.alibi,
            "alibi_is_lie": c.alibi_is_lie,
            "is_criminal": c.is_criminal,
        }
        for c in world.characters
    ]

    crime_payload = {
        "crime_type": crime.crime_type,
        "victim": crime.victim,
        "location": crime.location,
        "time_of_crime": crime.time_of_crime,
        "method": crime.method,
        "criminal_name": crime.criminal_name,
        "criminal_motive": crime.criminal_motive,
        "criminal_means": crime.criminal_means,
        "key_evidence_hidden": crime.key_evidence_hidden,
        "backstory_summary": crime.backstory_summary,
    }

    return f"""
You are generating discoverable clues for a crime mystery.

Hidden crime details:
{json.dumps(crime_payload, indent=2)}

Character list:
{json.dumps(character_payload, indent=2)}

Generate 8 clues.

Return ONLY valid JSON with exactly this structure:
{{
  "clues": [
    {{
      "clue_id": 1,
      "description": "...",
      "location": "...",
      "is_red_herring": false,
      "points_to": "...",
      "why_it_matters": "..."
    }}
  ]
}}

Requirements:
- Generate exactly 8 clues.
- Clues must follow naturally from the true crime and the characters.
- At least 2 clues must initially point toward innocent suspects.
- At least 2 clues must meaningfully connect to the real criminal.
- At least 1 clue should relate to a false alibi.
- At least 1 clue should be ambiguous until later interpretation.
- The clues should not instantly solve the crime when seen alone.
- "points_to" should name a character or a specific event/fact.
- clue_id values must be 1 through 8.

Return JSON only.
""".strip()


# Prompts the LLM and extracts clue data to our data structure
def generate_clues(world: StoryWorld) -> List[Clue]:
    raw = ask_llm(build_clues_prompt(world))
    data = extract_json(raw)
    
    clues = []
    for clue_data in data["clues"]:
        clue = Clue(
            clue_id=clue_data["clue_id"],
            description=clue_data["description"],
            location=clue_data["location"],
            discovered=False,
            is_red_herring=clue_data.get("is_red_herring", False),
            points_to=clue_data.get("points_to", ""),
            revealed_in_plot_point=-1
        )
        clues.append(clue)
    
    return clues


# Builds the prompt for the LLM to validate our clues
def build_clue_validation_prompt(world: StoryWorld, clues: List[Clue]) -> str:
    crime = world.crime_details
    if not crime:
        raise ValueError("No crime details in world.")

    payload = {
        "crime_details": {
            "crime_type": crime.crime_type,
            "victim": crime.victim,
            "location": crime.location,
            "time_of_crime": crime.time_of_crime,
            "method": crime.method,
            "criminal_name": crime.criminal_name,
            "criminal_motive": crime.criminal_motive,
            "criminal_means": crime.criminal_means,
            "backstory_summary": crime.backstory_summary,
        },
        "characters": [
            {
                "name": c.name,
                "role": c.role,
                "is_criminal": c.is_criminal,
                "alibi": c.alibi,
                "alibi_is_lie": c.alibi_is_lie,
            }
            for c in world.characters
        ],
        "clues": [
            {
                "clue_id": cl.clue_id,
                "description": cl.description,
                "location": cl.location,
                "is_red_herring": cl.is_red_herring,
                "points_to": cl.points_to,
            }
            for cl in clues
        ]
    }

    return f"""
You are validating the clue set for a crime mystery.

Data:
{json.dumps(payload, indent=2)}

Check:
1. Are there exactly 8 clues?
2. Do the clues arise naturally from the crime and character setup?
3. Do at least 2 clues point toward innocent suspects at first?
4. Do at least 2 clues connect meaningfully to the real criminal?
5. Is the mystery neither trivial nor impossible?
6. Are any clues redundant, contradictory, or disconnected?

Return ONLY valid JSON:
{{
  "is_valid": true,
  "issues": ["..."],
  "suggested_fixes": ["..."]
}}
""".strip()


# Prompts the LLM to validate our clue list
def validate_clues(world: StoryWorld, clues: List[Clue]) -> dict:
    raw = ask_llm(build_clue_validation_prompt(world, clues))
    return extract_json(raw)

# %%
# Builds the prompt to generate a countdown deadline and consequence for our solving story countdown mechanism
def build_countdown_prompt(world: StoryWorld) -> str:
    if not world.crime_details:
        raise ValueError("world.crime_details must exist first")

    crime = world.crime_details

    payload = {
        "crime_type": crime.crime_type,
        "victim": crime.victim,
        "location": crime.location,
        "time_of_crime": crime.time_of_crime,
        "method": crime.method,
        "criminal_name": crime.criminal_name,
        "criminal_motive": crime.criminal_motive,
        "backstory_summary": crime.backstory_summary,
    }

    return f"""
You are designing a countdown mechanism for a suspenseful detective story.

The countdown must:
- Be concrete and time-bound
- Be directly connected to the crime or investigation
- Create urgency that increases over time
- Make failure meaningful and irreversible

Crime context:
{json.dumps(payload, indent=2)}

Generate:
1. A specific countdown deadline (what event is approaching?)
2. A specific consequence if the detective fails before the deadline

Constraints:
- The deadline should feel natural to the scenario (not arbitrary)
- The consequence must be severe and story-relevant
- The consequence should make the truth harder or impossible to recover
- Avoid vague phrasing like "things get worse"

Examples of good countdowns:
- "By sunrise, the crime scene will be destroyed by the incoming storm."
- "In 24 hours, the prosecutor will formally charge the wrong suspect."
- "The suspect is scheduled to leave the country tonight."
- "A building demolition will erase crucial evidence."

Do not copy these exactly. Generate a new one specific to the crime.

Return ONLY valid JSON:
{{
  "countdown_deadline": "...",
  "countdown_consequence": "..."
}}
""".strip()


# Prompts the LLM and extracts data to StoryWorld data structure
def generate_countdown(world: StoryWorld) -> StoryWorld:
    raw = ask_llm(build_countdown_prompt(world))
    data = extract_json(raw)

    world.countdown_deadline = data["countdown_deadline"]
    world.countdown_consequence = data["countdown_consequence"]

    return world

# %%
# Function to populate StoryWorld data structure with characters, clues, and countdown mechanism
# Also runs validation functions of our generated characters and clues and outputs if the LLM detects an issue
def populate_story_world(world: StoryWorld) -> StoryWorld:
    if not world.crime_details:
        raise ValueError("Generate crime details first.")

    characters = generate_characters(world)
    char_validation = validate_characters(world, characters)
    if not char_validation["is_valid"]:
        print("Invalid characters -- try again")
        pprint(char_validation)

    world.characters = characters

    clues = generate_clues(world)
    clue_validation = validate_clues(world, clues)
    if not clue_validation["is_valid"]:
        print("Invalid clues -- try again")
        pprint(clue_validation)

    world.clues = clues

    world = generate_countdown(world)
    return world

# %%
def print_characters(world: StoryWorld):
    print("\nCHARACTERS")
    print("=" * 60)
    for c in world.characters:
        print(f"Name: {c.name}")
        print(f"Role: {c.role}")
        print(f"Description: {c.description}")
        print(f"Means: {c.means}")
        print(f"Motive: {c.motive}")
        print(f"Opportunity: {c.opportunity}")
        print(f"Alibi: {c.alibi}")
        print(f"Alibi is lie: {c.alibi_is_lie}")
        print(f"Is criminal: {c.is_criminal}")
        print("-" * 60)


def print_clues(world: StoryWorld):
    print("\nCLUES")
    print("=" * 60)
    for cl in sorted(world.clues, key=lambda x: x.clue_id):
        print(f"Clue #{cl.clue_id}")
        print(f"Description: {cl.description}")
        print(f"Location: {cl.location}")
        print(f"Points to: {cl.points_to}")
        print(f"Red herring: {cl.is_red_herring}")
        print("-" * 60)


def print_countdown(world: StoryWorld):
    print("\nCOUNTDOWN SETUP")
    print("=" * 60)
    print(f"Deadline: {world.countdown_deadline}")
    print(f"Consequence: {world.countdown_consequence}")

# %%
# Runner cell to populate story world with characters, clues, and countdown mechanism
world = populate_story_world(world)

print_characters(world)
print_clues(world)
print_countdown(world)
# Out:
# CHARACTERS
# ============================================================
# Name: Detective Inspector Anya Sharma
# Role: detective
# Description: A sharp and intuitive detective inspector from the city's Major Crimes Unit, known for her ability to connect seemingly disparate clues and her calm demeanor under pressure. She approaches each case with meticulous attention to detail and a keen understanding of human psychology.
# Means: N/A
# Motive: solve the case
# Opportunity: arrives after the crime to investigate
# Alibi: N/A
# Alibi is lie: False
# Is criminal: False
# ------------------------------------------------------------
# Name: Dr. Evelyn Reed
# Role: criminal
# Description: Elias Thorne's highly respected personal physician and long-time confidante. Elegant and composed in her late 50s, she projected an image of unwavering professionalism and dedication, often seen advising Thorne at public events.
# Means: As Thorne's physician, she possessed medical expertise, access to specialized substances (like neurotoxins) and equipment, and intimate knowledge of his health vulnerabilities. Her modified hatpin served as a discreet delivery system for the poison.
# Motive: Thorne was relentlessly blackmailing her, threatening to publicly expose a devastating professional secret at the gala: a severe misdiagnosis and subsequent cover-up that led to a patient's death. This exposure would ruin her career and lead to criminal charges, leaving her no perceived alternative.
# Opportunity: Her trusted position allowed her close, private access to Thorne throughout the evening, enabling her to administer the toxin subtly during a secluded conversation near the study between 9:45 PM and 10:15 PM.
# Alibi: Claims she was in a quiet conversation with a donor near the main staircase until about 9:50 PM, then went to refresh herself in the ladies' lounge until 10:20 PM, a period difficult to fully corroborate amidst the bustling gala.
# Alibi is lie: True
# Is criminal: True
# ------------------------------------------------------------
# Name: Julian Thorne
# Role: suspect
# Description: Elias Thorne's ambitious and often impulsive nephew, in his early 30s. He held a mid-level position at Thorne Industries and was frequently at odds with his uncle over company direction and his personal finances. He harbored deep resentment over being kept on a tight leash despite being a primary heir.
# Means: Access to Blackwood Manor. Could have purchased or acquired a substance (not necessarily a toxin) to incapacitate his uncle, or committed a physical act causing a 'collapse'. He is physically capable and resourceful.
# Motive: Financial desperation and resentment. Elias had recently threatened to cut him out of his will and expose Julian's significant gambling debts if he didn't toe the line. Julian desperately needed Thorne's fortune to solve his mounting financial troubles.
# Opportunity: Present at the gala, had several heated private discussions with Elias throughout the evening, one observed near the study around 9:40 PM.
# Description: A detailed forensic examination of Elias Thorne's body reveals a faint, almost imperceptible puncture mark on the left side of his neck, easily mistaken for a minor abrasion or skin imperfection.
# Location: Elias Thorne's body (initially overlooked)
# Points to: Method of murder (injection/hatpin), Dr. Evelyn Reed
# Red herring: False
# ------------------------------------------------------------
# Clue #8
# Description: During a thorough search of the study, investigators discover a decorative hatpin, missing its sharp tip, tucked away behind a loose floorboard. Trace amounts of a rare neurotoxin and Elias Thorne's DNA are later identified on the object.
# Location: Loose floorboard in the private study
# Points to: The murder weapon, the specific method (neurotoxin injection), Dr. Evelyn Reed
# Red herring: False
# ------------------------------------------------------------
#
# COUNTDOWN SETUP
# ============================================================
# Deadline: The imminent embalming of Elias Thorne's body, scheduled to take place within the next 12-18 hours.
# Consequence: If the detective fails to secure a forensic hold and prevent the embalming, the neurotoxin will be irreversibly flushed and masked from Thorne's system, rendering its detection impossible and cementing the official cause of death as natural causes, allowing Dr. Reed to escape justice entirely.

# %% [markdown]
# ## Phase 3: Iterative Loop / Meta Controller

# %%
# Helper function for countdown mechanism
def build_countdown_text(step_index: int, total_steps: int = 15) -> str:
    remaining = total_steps - step_index + 1

    if remaining > 10:
        urgency = "low but rising"
    elif remaining > 5:
        urgency = "moderate and increasingly serious"
    elif remaining > 2:
        urgency = "high"
    else:
        urgency = "extreme"

    return (
        f"COUNTDOWN: The detective has only {remaining} major investigative moves remaining "
        f"before the case reaches a point of no return. Urgency level: {urgency}."
    )

# %%
# Summarizes plot so far to pass as context to next LLM prompt
def build_plot_context(world: StoryWorld) -> str:
    if not world.crime_details:
        raise ValueError("world.crime_details is missing")

    crime = world.crime_details

    detective = next((c for c in world.characters if c.role == "detective"), None)
    if detective is None:
        raise ValueError("No detective found in world.characters")

    suspects = [c for c in world.characters if c.role in ("suspect", "criminal")]
    discovered_clues = world.discovered_clues()

    payload = {
        "crime_details": {
            "crime_type": crime.crime_type,
            "victim": crime.victim,
            "location": crime.location,
            "time_of_crime": crime.time_of_crime,
            "method": crime.method,
            "backstory_summary": crime.backstory_summary,
        },
        "detective": {
            "name": detective.name,
            "description": detective.description,
            "motive": detective.motive,
        },
        "active_suspects": [
            {
                "name": c.name,
                "role": c.role,
                "description": c.description,
                "means": c.means,
                "motive": c.motive,
                "opportunity": c.opportunity,
                "alibi": c.alibi,
                "alibi_is_lie": c.alibi_is_lie,
                "eliminated": c.eliminated,
            }
            for c in suspects if not c.eliminated
        ],
        "discovered_clues": [
            {
                "clue_id": cl.clue_id,
                "description": cl.description,
                "location": cl.location,
                "is_red_herring": cl.is_red_herring,
                "points_to": cl.points_to,
            }
            for cl in discovered_clues
        ],
        "undiscovered_clues": [
            {
                "clue_id": cl.clue_id,
                "description": cl.description,
                "location": cl.location,
                "is_red_herring": cl.is_red_herring,
                "points_to": cl.points_to,
            }
            for cl in world.clues if not cl.discovered
        ],
        "prior_plot_points": [
            {
                "index": p.index,
                "title": p.title,
                "description": p.description,
                "action_taken": p.action_taken,
                "outcome": p.outcome,
                "obstacle": p.obstacle,
                "suspense_score": p.suspense_score,
                "characters_involved": p.characters_involved,
                "clues_revealed": p.clues_revealed,
                "clues_used": p.clues_used,
            }
            for p in world.plot_points
        ]
    }

    return json.dumps(payload, indent=2)

# %%
# Prompt for generating next plot point
def build_next_plot_point_prompt(world: StoryWorld, step_index: int, total_steps: int = 15) -> str:
    detective = next((c for c in world.characters if c.role == "detective"), None)
    if detective is None:
        raise ValueError("No detective found")

    countdown_text = build_countdown_text(step_index, total_steps)

    detective_goal = (
        f"{detective.name} must identify the true criminal behind the "
        f"{world.crime_details.crime_type} of {world.crime_details.victim} before the final countdown expires."
    )

    deadline = getattr(world, "countdown_deadline", "")
    consequence = getattr(world, "countdown_consequence", "")
    
    countdown_block = f"""
    DEADLINE:
    {deadline}
    
    CONSEQUENCE:
    {consequence}
    """

    return f"""
You are the suspense-planning controller for a crime mystery.

Your job is to generate exactly ONE next plot point in a 15-step detective story.

This story must use suspense generation:
1. The audience cares about the detective and the victim.
2. The detective has a concrete goal.
3. Failure has dire consequences.
4. Each new plot point makes success harder, more urgent, or less likely.
5. Suspense comes from narrowing options, increasing uncertainty, and reducing chances to avert failure.
6. Do NOT resolve the full case early.

Detective goal:
{detective_goal}

{countdown_block}

{countdown_text}

Current story state:
{build_plot_context(world)}

Rules for this next plot point:
- This is plot point #{step_index} of {total_steps}.
- The detective must take a concrete action.
- That action must produce a meaningful outcome, but not fully solve the case unless this is the final plot point.
- Introduce or intensify an obstacle.
- Suspense must generally rise over time.
- Reveal 0, 1, or 2 clues at this step.
- Use already discovered clues when relevant.
- A clue can be revealed only once.
- You may eliminate at most one suspect in a single step.
- The detective should not identify the real criminal before plot point 13.
- Plot points 13-15 should feel like endgame escalation.
- A false lead, contradiction, missing evidence, time pressure, or witness unreliability can be used as obstacles.
- Keep the action grounded in crime solving, not action-movie spectacle.

Return ONLY valid JSON with exactly this structure:
{{
  "index": {step_index},
  "title": "...",
  "description": "...",
  "action_taken": "...",
  "outcome": "...",
  "obstacle": "...",
  "suspense_score": 0.0,
  "characters_involved": ["..."],
  "clues_revealed": [1, 2],
  "clues_used": [1, 2],
  "suspect_eliminated": "Name or empty string",
  "countdown_note": "How the countdown pressure changed in this step"
}}

Constraints on suspense_score:
- It should usually increase over time.
- Early steps: around 0.25 to 0.45
- Middle steps: around 0.45 to 0.75
- Late steps: around 0.75 to 0.98

Return JSON only.
""".strip()

# %%
# Integrate/apply new plot point to story
def apply_plot_point_to_world(world: StoryWorld, data: dict) -> PlotPoint:
    plot_point = PlotPoint(
        index=data["index"],
        title=data["title"],
        description=data["description"],
        action_taken=data["action_taken"],
        outcome=data["outcome"],
        obstacle=data["obstacle"],
        suspense_score=float(data["suspense_score"]),
        characters_involved=data.get("characters_involved", []),
        clues_revealed=data.get("clues_revealed", []),
        clues_used=data.get("clues_used", [])
    )

    # Mark newly revealed clues as discovered
    for clue_id in plot_point.clues_revealed:
        clue = world.get_clue(clue_id)
        if clue:
            clue.discovered = True
            clue.revealed_in_plot_point = plot_point.index

    # Eliminate suspect if applicable
    suspect_name = data.get("suspect_eliminated", "").strip()
    if suspect_name:
        character = world.get_character(suspect_name)
        if character and character.role in ("suspect", "criminal") and not character.is_criminal:
            character.eliminated = True
            character.notes.append(f"Eliminated in plot point {plot_point.index}")

    world.plot_points.append(plot_point)
    return plot_point

# %%
# Prompt for validating plot construction
def build_plot_point_validation_prompt(world: StoryWorld, candidate: dict, total_steps: int = 15) -> str:
    return f"""
You are validating one plot point in a suspenseful detective story.

Current story state:
{build_plot_context(world)}

Candidate plot point:
{json.dumps(candidate, indent=2)}

Check:
1. Is the detective taking a concrete investigative action?
2. Does the plot point increase or maintain suspense appropriately?
3. Does it avoid solving the whole case too early?
4. Are clue reveals valid and non-contradictory?
5. Is any suspect elimination justified?
6. Is the obstacle meaningful?
7. Is this consistent with a countdown-based suspense structure?

Return ONLY valid JSON:
{{
  "is_valid": true,
  "issues": ["..."],
  "suggested_fixes": ["..."]
}}
""".strip()


def validate_plot_point(world: StoryWorld, candidate: dict) -> dict:
    raw = ask_llm(build_plot_point_validation_prompt(world, candidate))
    return extract_json(raw)

# %%
# Prompts LLM with build_next_plot_point_prompt, validates, and integrates to story world object
def generate_next_plot_point(world: StoryWorld, step_index: int, total_steps: int = 15, max_attempts: int = 3) -> PlotPoint:
    last_candidate = None

    # Validation / retry mechanism
    for attempt in range(max_attempts):
        prompt = build_next_plot_point_prompt(world, step_index, total_steps)
        raw = ask_llm(prompt)
        candidate = extract_json(raw)
        last_candidate = candidate

        validation = validate_plot_point(world, candidate)

        if validation.get("is_valid", False):
            return apply_plot_point_to_world(world, candidate)

    # fallback: use the last candidate even if imperfect
    if last_candidate is None:
        raise ValueError(f"Failed to generate plot point {step_index}")

    return apply_plot_point_to_world(world, last_candidate)
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.

# %% [markdown]
# ### Meta Controller

# %%
# Meta controller that progresses story by introducing plot points and injecting suspense
def generate_plot_points(world: StoryWorld, total_steps: int = 15) -> StoryWorld:
    if not world.crime_details:
        raise ValueError("Generate crime details first.")
    if not world.characters:
        raise ValueError("Generate characters first.")
    if not world.clues:
        raise ValueError("Generate clues first.")

    world.plot_points = []

    for step_index in range(1, total_steps + 1):
        print(f"Generating plot point {step_index}/{total_steps}...")
        plot_point = generate_next_plot_point(world, step_index, total_steps)
        print(f"  -> {plot_point.title} (suspense={plot_point.suspense_score:.2f})")

    return world

# %%
# Fully validates plot post-generation
def build_full_plot_validation_prompt(world: StoryWorld) -> str:
    payload = {
        "crime_type": world.crime_details.crime_type if world.crime_details else "",
        "victim": world.crime_details.victim if world.crime_details else "",
        "plot_points": [
            {
                "index": p.index,
                "title": p.title,
                "description": p.description,
                "action_taken": p.action_taken,
                "outcome": p.outcome,
                "obstacle": p.obstacle,
                "suspense_score": p.suspense_score,
                "characters_involved": p.characters_involved,
                "clues_revealed": p.clues_revealed,
                "clues_used": p.clues_used,
            }
            for p in world.plot_points
        ],
        "remaining_active_suspects": [c.name for c in world.active_suspects()],
        "discovered_clues": [cl.clue_id for cl in world.discovered_clues()]
    }

    return f"""
You are validating the full suspense arc of a 15-point detective mystery.

Data:
{json.dumps(payload, indent=2)}

Check:
1. Do the 15 plot points form a coherent progression?
2. Does suspense generally rise?
3. Does the countdown mechanism feel meaningful?
4. Is the case not solved too early?
5. Are the final 3 plot points endgame escalation?
6. Are clue reveals paced well?
7. Are there any repetitive or filler beats?

Return ONLY valid JSON:
{{
  "is_valid": true,
  "issues": ["..."],
  "suggested_fixes": ["..."],
  "arc_score": 0.0
}}
""".strip()


def validate_full_plot_arc(world: StoryWorld) -> dict:
    raw = ask_llm(build_full_plot_validation_prompt(world))
    return extract_json(raw)

# %%
def print_plot_points(world: StoryWorld):
    print("\nPLOT POINTS")
    print("=" * 80)

    for p in sorted(world.plot_points, key=lambda x: x.index):
        print(f"[{p.index}] {p.title}")
        print(f"Description: {p.description}")
        print(f"Action Taken: {p.action_taken}")
        print(f"Outcome: {p.outcome}")
        print(f"Obstacle: {p.obstacle}")
        print(f"Suspense Score: {p.suspense_score:.2f}")
        print(f"Characters Involved: {p.characters_involved}")
        print(f"Clues Revealed: {p.clues_revealed}")
        print(f"Clues Used: {p.clues_used}")
        print("-" * 80)

# %%
# Runner cell to generate plot points and validate story

world = generate_plot_points(world, total_steps=15)
print_plot_points(world)

arc_validation = validate_full_plot_arc(world)
print("\nFULL ARC VALIDATION")
pprint(arc_validation)
# Out:
# Generating plot point 1/15...
#   -> A Faint Mark and Official Reluctance (suspense=0.38)
# Generating plot point 2/15...
#   -> A Prescription and Evasive Answers (suspense=0.45)
# Generating plot point 3/15...
#   -> A Grudging Concession and a Cryptic Message (suspense=0.52)
# Generating plot point 4/15...
#   -> A Divided Focus and the Other 'E.R.' (suspense=0.60)
# Generating plot point 5/15...
#   -> The Hidden Needle and a Molecular Maze (suspense=0.68)
# Generating plot point 6/15...
#   -> A Match, A Scar, and a Silent Clock (suspense=0.73)
# Generating plot point 7/15...
#   -> A Desperate Appeal and a Crippling Deadline (suspense=0.79)
# Generating plot point 8/15...
#   -> A Fading Residue (suspense=0.85)
# Generating plot point 9/15...
#   -> A Plea to the Court, A Final, Fading Hope (suspense=0.89)
# Generating plot point 10/15...
#   -> The Faltering Algorithm (suspense=0.92)
# Generating plot point 11/15...
#   -> A Fragmented Whisper in the Data (suspense=0.94)
# Generating plot point 12/15...
#   -> The Last Echo (suspense=0.96)
# Generating plot point 13/15...
#   -> A Desperate Sprint and a Frantic Halt (suspense=0.97)
# Generating plot point 14/15...
#   -> A Glimmer, Tainted (suspense=0.98)
# Generating plot point 15/15...
#   -> The Verdict of the Tainted Truth (suspense=0.99)
#
# PLOT POINTS
# ================================================================================
# [1] A Faint Mark and Official Reluctance
# Description: Unconvinced by the initial assessment of natural causes, Detective Inspector Anya Sharma pushes for a more thorough forensic examination of Elias Thorne's body. Simultaneously, she initiates a formal request to the Chief Medical Examiner for an immediate, indefinite forensic hold, hoping to prevent the scheduled embalming. Her initial interview with Dr. Evelyn Reed, Thorne's personal physician, reveals a composed professional seemingly unfazed by the sudden death.
# Action Taken: DI Sharma requests an immediate, detailed forensic autopsy on Elias Thorne, specifically focusing on toxicology, and formally petitions the Chief Medical Examiner's office for a forensic hold to prevent embalming. She also conducts a preliminary interview with Dr. Evelyn Reed.
# Outcome: While the Chief Medical Examiner agrees to an expedited but standard autopsy, they express significant reluctance to grant an indefinite forensic hold, citing the initial lack of suspicious findings and pressure from the influential Thorne family for a swift funeral. However, the forensic team, under Sharma's specific instructions, makes a critical, almost imperceptible discovery: a faint puncture mark on Thorne's neck. Additionally, a microscopic emerald-green synthetic fiber is found clinging to his tuxedo lapel. Dr. Reed's initial interview provides no immediate red flags, as she maintains a professional and collected demeanor, attributing Thorne's demise to his known heart condition and the stress of the gala.
# Obstacle: The Chief Medical Examiner's office, influenced by the Thorne family and their own preliminary findings, resists an indefinite forensic hold, tightening the embalming deadline and forcing Sharma to produce concrete evidence quickly. The crucial physical evidence (puncture mark) is so subtle it was nearly missed, highlighting the difficulty of proving murder against an official 'natural causes' ruling.
# Suspense Score: 0.38
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Evelyn Reed', 'Chief Medical Examiner', 'Forensic Team']
# Clues Revealed: [7, 1]
# Clues Used: []
# --------------------------------------------------------------------------------
# [2] A Prescription and Evasive Answers
# Description: Armed with the new forensic findings—the faint puncture mark and the emerald fiber—Detective Inspector Sharma confronts Dr. Evelyn Reed a second time. Sharma pointedly questions Reed about Thorne's recent medical state, specifically any new prescriptions or unusual health concerns in the days leading up to the gala, while subtly observing her reactions when the microscopic puncture mark and the peculiar fiber are mentioned. Concurrently, Sharma tasks her forensic team with an urgent, meticulous search through Thorne's personal effects, particularly any discarded items that might reveal recent medical activity.
# Action Taken: DI Sharma conducts a targeted second interview with Dr. Evelyn Reed, focusing on recent medical history and subtly introducing the new forensic evidence. Her team performs an expedited, thorough search of Elias Thorne's discarded personal effects from the crime scene.
# Outcome: Dr. Reed, though outwardly composed, becomes noticeably more guarded and terse when pressed about Thorne's specific health leading up to the gala, offering only vague allusions to his 'fragile constitution' and dismissing the puncture mark as an insignificant abrasion. She unequivocally denies any knowledge of an emerald fiber. However, the forensic team, working against the clock, discovers a crumpled prescription label in Thorne's discarded coat pocket. It's for a powerful sedative, dated the day of the gala, with a dosage far exceeding typical recommendations, and signed by Dr. Evelyn Reed. This directly contradicts Reed's initial portrayal of Thorne's stable health and raises immediate, serious questions about her involvement.
# Obstacle: The discovery of the high-dosage sedative (Clue 2) introduces a new layer of complexity. While highly suspicious, it also offers a plausible alternative explanation for Thorne's collapse—a 'miscalculation' or 'accident' involving medication—which could be leveraged by the Thorne family and the Chief Medical Examiner to justify denying a full neurotoxin screen and proceed with embalming. Sharma now faces the risk of her murder theory being diluted by a 'medical mishap' narrative, making it even harder to secure the crucial forensic hold before the deadline. Dr. Reed is now aware Sharma is digging into the medical details.
# Suspense Score: 0.45
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Evelyn Reed', 'Forensic Team']
# Clues Revealed: [2]
# Clues Used: [1, 7]
# --------------------------------------------------------------------------------
# Obstacle: The emergence of Eleanor Vance as a highly suspicious 'E.R.' with a confessed motive and a now-broken alibi (Clue 5) creates a potent red herring. This forces Detective Sharma to divide her increasingly limited resources and investigative focus between two compelling suspects, significantly increasing the risk of pursuing a false lead. With the Chief Medical Examiner only granting a *limited* neurotoxin screen and the embalming deadline rapidly approaching, this diversion of attention makes the crucial task of identifying the true poison and securing a full forensic hold even more challenging and less likely to succeed in time.
# Suspense Score: 0.60
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Evelyn Reed', 'Eleanor Vance', 'Digital Forensics Team']
# Clues Revealed: [5]
# Clues Used: [1, 4]
# --------------------------------------------------------------------------------
# [5] The Hidden Needle and a Molecular Maze
# Description: Detective Inspector Sharma, acutely aware of the embalming deadline and the Chief Medical Examiner's strict limitations on forensic testing, makes a calculated risk. Despite the compelling red herring of Eleanor Vance's broken alibi (Clue 5) and motive, Sharma feels a lingering conviction about the faint puncture mark (Clue 7) and the unique emerald fiber (Clue 1). She tasks her forensic team with an intensive, almost invasive, secondary search of Thorne's private study, focusing on concealed spaces or hidden compartments where a small, sharp instrument could be stashed.
# Action Taken: DI Sharma directs her forensic team to conduct a meticulously thorough and invasive secondary search of Elias Thorne's private study, specifically targeting hidden compartments, loose floorboards, and any discreetly concealed areas for a potential murder weapon, emphasizing the small scale implied by the puncture mark.
# Outcome: The renewed search yields a critical discovery: hidden behind a loose floorboard in the study, investigators find a decorative hatpin, its sharp tip noticeably absent (Clue 8). Forensic analysis quickly confirms the presence of a neurotoxin on the remnants of the tip and, crucially, trace amounts of Elias Thorne's DNA. The toxin is identified as a highly potent, rare variety, known for its rapid action and extreme difficulty in post-mortem detection.
# Obstacle: The identification of a *specific, rare neurotoxin* on the hatpin (Clue 8) is a monumental breakthrough, directly confirming the murder method. However, this success comes with a crushing new burden: the identified neurotoxin is precisely the type that would be exceptionally challenging to detect within a human system, especially with the *limited* toxicology screen (from Plot Point 3) grudgingly approved by the Chief Medical Examiner. The clock is now ticking louder than ever; Sharma has the weapon and the poison, but proving it was *in Thorne's body* before embalming becomes a desperate race against an almost impossible forensic hurdle. The direct link between *this specific hatpin* and Dr. Evelyn Reed, beyond the general emerald fiber (Clue 1) remains circumstantial, leaving the 'E.R.' ambiguity (Clue 4) still unresolved for concrete proof.
# Suspense Score: 0.68
# Characters Involved: ['Detective Inspector Anya Sharma', 'Forensic Team', 'Chief Medical Examiner']
# Clues Revealed: [8]
# Clues Used: [1, 7, 4, 5]
# --------------------------------------------------------------------------------
# [6] A Match, A Scar, and a Silent Clock
# Description: With the discovery of the modified hatpin (Clue 8) and the specific, rare neurotoxin, Detective Inspector Sharma has undeniable proof of murder. However, the Chief Medical Examiner's reluctance to grant a full toxicology panel leaves the critical link to Thorne's system unconfirmed. Sharma, prioritizing the strongest lead and racing against the embalming deadline, moves decisively to solidify the case against Dr. Evelyn Reed, obtaining an urgent search warrant for her residence and clinic. She hopes to find direct connections to the murder weapon and the elusive emerald fiber.
# Characters Involved: ['Detective Inspector Anya Sharma', 'High Court Judge', 'Chief Medical Examiner']
# Clues Revealed: []
# Clues Used: [1, 7, 8, 9, 10]
# --------------------------------------------------------------------------------
# [8] A Fading Residue
# Description: Detective Inspector Sharma, facing the High Court's non-negotiable 6-hour ultimatum, makes a desperate appeal to Dr. Anya Petrova, a brilliant but notoriously private forensic toxicologist known for her expertise in rare compounds. Sharma, armed with the precise identification of the rare neurotoxin from the hatpin (Clue 8), implores Dr. Petrova to perform an emergency, hyper-focused analysis of Thorne's most viable tissue samples, searching for even the most minute evidence of the poison before the final, irreversible embalming.
# Action Taken: DI Sharma directly contacts Dr. Anya Petrova, a renowned forensic toxicologist, requesting an immediate, hyper-focused analysis of Elias Thorne's tissue samples, specifically targeting the rare neurotoxin identified on the murder weapon (Clue 8), emphasizing the strict 6-hour judicial deadline.
# Outcome: Dr. Petrova agrees to undertake the daunting task. Utilizing cutting-edge techniques and working under immense pressure, she successfully identifies a unique, highly unstable *metabolite* (Clue 11) of the specific neurotoxin in a previously preserved tissue sample from Thorne. This is a critical breakthrough, unequivocally confirming the neurotoxin had been present and processed by Thorne's system. However, the original neurotoxin itself, which the judge demanded 'unassailable, direct forensic proof' of, remains undetectable within the remaining samples.
# Obstacle: While the discovery of the neurotoxin's metabolite (Clue 11) is a scientific triumph, its highly unstable nature means it degrades rapidly, making precise quantification and presentation as 'unassailable, direct forensic proof' incredibly challenging. The High Court judge specifically demanded proof of the *neurotoxin itself*, not its fleeting byproduct. With only a crucial few hours left before the final embalming deadline, Dr. Petrova races against time to stabilize the sample and formulate a report that will satisfy the judge's strict demands, knowing that the absence of the original toxin could still lead to the case being dismissed and the embalming proceeding, cementing Dr. Reed's escape.
# Suspense Score: 0.85
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Anya Petrova']
# Clues Revealed: [11]
# Clues Used: [8]
# --------------------------------------------------------------------------------
# [9] A Plea to the Court, A Final, Fading Hope
# Description: Detective Inspector Sharma, accompanied by a visibly weary but determined Dr. Anya Petrova, returns to the High Court. Dr. Petrova meticulously presents the findings of the neurotoxin metabolite (Clue 11), explaining its scientific significance and arguing that its unstable presence unequivocally confirms the neurotoxin was in Thorne's system, despite the rapid degradation of the original compound. Sharma appeals directly to the judge's sense of justice, emphasizing the overwhelming circumstantial evidence against Dr. Evelyn Reed.
# Action Taken: DI Sharma and Dr. Anya Petrova formally present the evidence of the neurotoxin's metabolite (Clue 11) to the High Court judge, arguing that it fulfills the demand for forensic proof of the toxin's presence in Elias Thorne's body.
# Outcome: The High Court judge, while acknowledging the scientific complexity and Dr. Petrova's expertise, remains unconvinced that the *metabolite alone*, given its instability and the absence of the original toxin, constitutes the 'unassailable, direct forensic proof' initially demanded. He expresses severe reservations about setting a legal precedent based on a fleeting byproduct. However, he offers a final, incredibly narrow concession: he will grant a *mere 3-hour, non-renewable extension* to the embalming deadline, but only for a single, last-ditch attempt to utilize a highly experimental, specialized mass spectrometry technique on Thorne's most viable remaining tissue sample. If this fails to detect *any* trace of the original neurotoxin, the embalming will proceed immediately.
# Obstacle: The High Court judge's ruling creates an almost insurmountable obstacle. The remaining time has been slashed from 6 hours to a mere 3, intensifying the deadline pressure to an extreme degree. Furthermore, the final investigative option is now limited to a single, highly experimental forensic technique that has an uncertain chance of success, especially given the toxin's elusive nature. Sharma's options have been drastically narrowed, increasing the uncertainty and making the successful detection of the neurotoxin in Thorne's body a desperate, long-shot gamble against the clock.
# Suspense Score: 0.89
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Anya Petrova', 'High Court Judge']
# Clues Revealed: []
# Clues Used: [11]
# --------------------------------------------------------------------------------
# [10] The Faltering Algorithm
# Description: With the High Court's non-negotiable 3-hour clock ticking down to zero, Detective Inspector Sharma stands shoulder-to-shoulder with Dr. Anya Petrova in the high-tech toxicology lab. Every second is critical as Dr. Petrova, under Sharma's watchful eye, begins to prepare Thorne's remaining tissue sample for the highly experimental, specialized mass spectrometry technique – their final, desperate chance to detect the elusive neurotoxin within his system.
# Action Taken: DI Sharma oversees Dr. Anya Petrova as she initiates the highly experimental, specialized mass spectrometry technique on Elias Thorne's most viable remaining tissue sample, aiming to detect the original neurotoxin within the strict 3-hour deadline set by the High Court.
# Outcome: Just as the complex machinery sputters to life, a critical, unforeseen software error halts the process. The experimental algorithm, designed for this unique toxin, encounters a severe compatibility issue with the lab's specific instrument configuration. Dr. Petrova and her team immediately plunge into troubleshooting, but the problem is deep-seated, demanding a time-consuming reconfiguration and recalibration, bleeding precious minutes from their dwindling 3-hour window. The initial run, before the error, yields only ambiguous, unreadable data.
# Obstacle: The cutting-edge, experimental nature of the mass spectrometry technique has introduced a critical, unforeseen technical failure. This software malfunction, requiring immediate and extensive recalibration, consumes a significant portion of the precious 3-hour judicial extension, making successful detection of the original neurotoxin within the remaining, severely diminished timeframe an almost impossible feat. The uncertainty and the rapidly expiring deadline create an intense feeling of impending failure.
# Suspense Score: 0.92
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Anya Petrova', 'Lab Technicians']
# Clues Revealed: []
# Clues Used: [11, 8]
# --------------------------------------------------------------------------------
# [11] A Fragmented Whisper in the Data
# Description: With the High Court's non-negotiable 3-hour clock ticking down to zero and the experimental mass spectrometry still battling a critical software error, Detective Inspector Sharma makes a desperate, high-stakes decision. She urges Dr. Anya Petrova to attempt a high-risk, truncated version of the experimental scan, even if it means sacrificing precision, in a desperate bid to extract any usable data before the final, irreversible deadline.
# Action Taken: DI Sharma presses Dr. Anya Petrova to initiate a high-speed, compromised scan on Elias Thorne's tissue sample using the partially functional mass spectrometer, accepting the inherent risks of data integrity and potential equipment failure, as the 3-hour deadline rapidly dwindles.
# Outcome: Dr. Petrova, under extreme duress and risking equipment stability, manages to force the experimental mass spectrometer through a heavily abbreviated, high-speed run. The system produces a highly unstable data stream showing erratic, almost imperceptible spikes that *could* be indicative of the neurotoxin (Clue 8), but the readings are far too noisy and inconsistent to be considered conclusive. The persistent software error prevented a clean, verifiable scan, yielding a 'fragmented whisper' of data rather than clear evidence.
# Obstacle: The hasty, compromised scan yields only highly ambiguous and unreliable data. While it suggests the possible presence of the neurotoxin, it utterly fails to meet the judge's demand for 'unassailable, direct forensic proof.' Crucially, the remaining time on the 3-hour extension is now practically nonexistent—mere minutes, perhaps seconds, remain. Sharma faces an impossible choice: present this inconclusive data and risk immediate dismissal, or push for an even more desperate, practically impossible, last-second action with no time left. The embalming is now imminent, and the chance to secure a forensic hold hangs by a thread.
# Suspense Score: 0.94
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Anya Petrova', 'Lab Technicians']
# Clues Revealed: []
# Clues Used: [8]
# --------------------------------------------------------------------------------
# [12] The Last Echo
# Description: With the mass spectrometer refusing a definitive reading and mere seconds left before the final deadline, Detective Inspector Sharma refuses to give up. Her mind races, replaying every detail, every piece of evidence. She remembers the high-dosage sedative (Clue 2) prescribed by Dr. Reed, and the unique properties of the rare neurotoxin (Clue 8) from the hatpin. A desperate thought sparks: what if the neurotoxin's interaction with the sedative created a unique, more stable chemical signature that the previous tests overlooked? She urgently directs Dr. Petrova to re-process the raw, erratic data (from Plot Point 11) for this specific chemical interaction.
# Action Taken: DI Sharma, with only moments to spare, instructs Dr. Anya Petrova to perform an immediate, targeted re-analysis of the raw, unstable mass spectrometry data, specifically filtering for a unique interaction byproduct formed between the identified neurotoxin (Clue 8) and the high-dosage sedative (Clue 2) found in Thorne's system.
# Outcome: Against all scientific expectations and with seconds melting away, Dr. Petrova's rapid re-analysis of the noisy data reveals a faint but distinct and scientifically verifiable *molecular signature* (Clue 12) of the neurotoxin-sedative interaction. This isn't the neurotoxin itself, but undeniable proof that *both* were present and reacted within Elias Thorne's body. However, as the final data flickers onto the screen, a frantic call comes through: the embalming procedure has just begun.
# Obstacle: Sharma finally possesses the 'unassailable, direct forensic proof' the judge demanded, but it arrives *literally at the exact moment* the embalming procedure is initiated. The 3-hour extension has run out, and the Chief Medical Examiner, having fulfilled his court-mandated obligations, allowed the procedure to commence. Sharma now faces the physical, bureaucratic impossibility of halting an active embalming, making the successful preservation of evidence (and thus the conviction of Dr. Reed) contingent on an immediate, perhaps physical, intervention against official orders. The evidence is there, but the window to preserve it is physically closing.
# Suspense Score: 0.96
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Anya Petrova', 'Chief Medical Examiner (off-screen)']
# Clues Revealed: [12]
# Clues Used: [2, 8]
# --------------------------------------------------------------------------------
# [13] A Desperate Sprint and a Frantic Halt
# Description: With the discovery of the neurotoxin-sedative molecular signature (Clue 12) finally providing the 'unassailable, direct forensic proof' but the embalming procedure already initiated, Detective Inspector Sharma makes a split-second, audacious decision. Ignoring all protocols and bureaucratic resistance, she and Dr. Anya Petrova immediately abandon the lab and race towards the hospital morgue, intent on physically intervening and halting the embalming process at any cost, before the irreversible flushing of evidence.
# Action Taken: DI Sharma, alongside Dr. Anya Petrova, abandons the lab and makes a desperate, unauthorized sprint to the hospital morgue, with the explicit intent of physically halting the active embalming procedure of Elias Thorne's body, armed only with the newly discovered molecular signature (Clue 12) as their justification.
# Outcome: Sharma bursts into the morgue, confronting a bewildered and indignant Chief Medical Examiner and his staff, who are already several minutes into the embalming process. Using her authority, and with Petrova quickly displaying the new forensic report on a tablet, Sharma demands an immediate, absolute halt. The CME, initially furious at the unauthorized intrusion, is visibly shaken by the undeniable scientific proof of the neurotoxin's presence and reluctantly orders the procedure stopped. However, the embalming fluid has already been partially introduced into Thorne's system, and the initial flushing has begun, potentially compromising the remaining forensic integrity of the most crucial samples.
# Obstacle: While the embalming has been halted, the procedure was already underway. This means irreversible damage has likely been done to Elias Thorne's body, potentially flushing out critical remaining traces of the neurotoxin and making any future, more comprehensive testing extremely challenging, if not impossible, to yield definitive results. The Chief Medical Examiner is now openly hostile and will actively resist any further intrusive forensic requests, demanding a clear, viable path forward given the partial contamination. Sharma has stopped the full flushing, but the evidence is now severely compromised, and her window for *unambiguous* detection has shrunk to a near-zero possibility.
# Suspense Score: 0.97
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Anya Petrova', 'Chief Medical Examiner', 'Morgue Staff']
# Clues Revealed: []
# Clues Used: [12]
# --------------------------------------------------------------------------------
# [14] A Glimmer, Tainted
# Description: With the embalming process halted but the evidence already partially compromised, Detective Inspector Sharma wastes no time. She immediately asserts her authority over the hostile Chief Medical Examiner, instructing Dr. Anya Petrova to take charge of Elias Thorne's body with absolute priority. Sharma's directive is clear: identify and meticulously isolate any and all tissue samples that might still retain forensic integrity for detecting the neurotoxin or its unique molecular signature (Clue 12), despite the damage inflicted by the initial embalming fluid. Simultaneously, Dr. Petrova is tasked with preparing an urgent forensic report detailing the exact extent of the compromise and what, if anything, can still be salvaged for a legally admissible case.
# Action Taken: DI Sharma directs Dr. Anya Petrova to assume immediate control of Elias Thorne's body, instructing her to perform an emergency, highly selective forensic preservation of all potentially viable tissue samples. Petrova is also tasked with rapidly compiling a report on the impact of the partial embalming on the remaining evidence, focusing on the neurotoxin and its molecular signature (Clue 12).
# Outcome: Working at a frantic pace, Dr. Petrova manages to secure a handful of minute, peripheral tissue samples from areas of Thorne's body less affected by the initial embalming flush. While these samples still definitively contain the unique neurotoxin-sedative molecular signature (Clue 12) – proof of the interaction – Petrova's preliminary analysis confirms that the embalming chemicals have severely diluted and structurally altered the remaining traces. She delivers a grim assessment: while the *presence* of the molecular signature is confirmed, scientifically proving the *original concentration* or the *direct, unaltered presence* of the raw neurotoxin (Clue 8) beyond a shadow of a doubt in these now chemically modified samples is an almost impossible forensic feat. The evidence is there, but its pristine, legally 'unassailable' state is gone.
# Obstacle: The partial embalming has not only diluted but chemically altered the remaining, salvaged evidence. This creates an unprecedented and crippling forensic and legal challenge. While the molecular signature (Clue 12) still undeniably proves the neurotoxin's interaction within Thorne's body, the embalming process has fundamentally compromised the ability to meet the court's strict demand for 'unassailable direct proof' of the *original* neurotoxin's presence or its lethal dosage. Sharma now faces the almost impossible task of presenting severely compromised, chemically altered evidence to a skeptical judge and prosecutor, knowing that Dr. Reed's defense will relentlessly attack the integrity and admissibility of any findings from a partially embalmed body. The legal pathway to conviction has become fraught with uncertainty and near-insurmountable hurdles.
# Suspense Score: 0.98
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Anya Petrova', 'Chief Medical Examiner']
# Clues Revealed: []
# Clues Used: [12, 8, 2]
# --------------------------------------------------------------------------------
# [15] The Verdict of the Tainted Truth
# Description: With the salvaged but compromised evidence (Clue 12) confirming the neurotoxin-sedative interaction in Thorne's body, Detective Inspector Sharma and Dr. Anya Petrova face the High Court judge one final time. Sharma presents Dr. Petrova's grim but irrefutable report on the molecular signature and the extent of the embalming's impact, arguing forcefully that despite the damage, this unequivocally proves murder. She pushes for a permanent forensic hold on Thorne's body and demands Dr. Evelyn Reed's immediate arrest.
# Action Taken: DI Sharma, supported by Dr. Anya Petrova and her report detailing the neurotoxin-sedative molecular signature (Clue 12) and the compromised state of the evidence, makes a final, urgent appeal to the High Court judge for a permanent forensic hold on Elias Thorne's body and the immediate arrest of Dr. Evelyn Reed for murder.
# Outcome: The High Court judge, presented with the undeniable, albeit chemically altered, proof of the neurotoxin's presence and interaction within Thorne's body, rules that there is sufficient evidence to prevent further embalming and to issue an immediate arrest warrant for Dr. Evelyn Reed. Dr. Reed is apprehended and formally charged with the murder of Elias Thorne. The embalming is permanently halted, securing the remaining evidence.
# Obstacle: While Dr. Reed is arrested and the embalming averted, the partial embalming and the subsequent chemical alteration of the crucial forensic evidence (Clue 12) present a formidable new challenge for the prosecution. The defense is now certain to exploit the compromised nature of the samples, casting doubt on the lethal dosage and the overall integrity and admissibility of the evidence in court, making the upcoming trial an arduous and uncertain battle for a conviction. The Chief Medical Examiner, thoroughly humiliated and at odds with Sharma, will likely continue to be an uncooperative force in the legal proceedings.
# Suspense Score: 0.99
# Characters Involved: ['Detective Inspector Anya Sharma', 'Dr. Anya Petrova', 'High Court Judge', 'Dr. Evelyn Reed', 'Chief Medical Examiner']
# Clues Revealed: []
# Clues Used: [12, 8, 2]
# --------------------------------------------------------------------------------
#
# FULL ARC VALIDATION
# {'arc_score': 0.98, 'is_valid': True, 'issues': [], 'suggested_fixes': []}

# %% [markdown]
# ## Phase 4: Validation + Final Narrative Assembly

# %%
# Functions for post-generation consistency check

def build_consistency_check_prompt(world: StoryWorld) -> str:
    payload = {
        "crime_details": {
            "crime_type": world.crime_details.crime_type if world.crime_details else "",
            "victim": world.crime_details.victim if world.crime_details else "",
            "location": world.crime_details.location if world.crime_details else "",
            "time_of_crime": world.crime_details.time_of_crime if world.crime_details else "",
            "method": world.crime_details.method if world.crime_details else "",
            "criminal_name": world.crime_details.criminal_name if world.crime_details else "",
            "criminal_motive": world.crime_details.criminal_motive if world.crime_details else "",
            "criminal_means": world.crime_details.criminal_means if world.crime_details else "",
            "backstory_summary": world.crime_details.backstory_summary if world.crime_details else "",
        },
        "characters": [
            {
                "name": c.name,
                "role": c.role,
                "description": c.description,
                "means": c.means,
                "motive": c.motive,
                "opportunity": c.opportunity,
                "alibi": c.alibi,
                "alibi_is_lie": c.alibi_is_lie,
                "is_criminal": c.is_criminal,
                "eliminated": c.eliminated,
                "notes": c.notes,
            }
            for c in world.characters
        ],
        "clues": [
            {
                "clue_id": cl.clue_id,
                "description": cl.description,
                "location": cl.location,
                "discovered": cl.discovered,
                "is_red_herring": cl.is_red_herring,
                "points_to": cl.points_to,
                "revealed_in_plot_point": cl.revealed_in_plot_point,
            }
            for cl in world.clues
        ],
        "plot_points": [
            {
                "index": p.index,
                "title": p.title,
                "description": p.description,
                "action_taken": p.action_taken,
                "outcome": p.outcome,
                "obstacle": p.obstacle,
                "suspense_score": p.suspense_score,
                "characters_involved": p.characters_involved,
                "clues_revealed": p.clues_revealed,
                "clues_used": p.clues_used,
            }
            for p in sorted(world.plot_points, key=lambda x: x.index)
        ]
    }

    return f"""
You are checking a crime mystery story plan for contradictions and logic problems.

Review the following story materials:
{json.dumps(payload, indent=2)}

Check for:
1. Character contradictions
2. Clue contradictions
3. Impossible timeline issues
4. Plot point outcomes that conflict with later events
5. Eliminated suspects acting as if still viable later without explanation
6. Clues that appear without being revealed
7. Any mismatch between the hidden crime and the detective's reconstructed story
8. Whether the final solution points to the real criminal

Return ONLY valid JSON in exactly this format:
{{
  "is_consistent": true,
  "issues": [
    "...",
    "..."
  ],
  "summary": "Brief overall judgment."
}}
""".strip()
    

def run_consistency_check(world: StoryWorld) -> dict:
    raw = ask_llm(build_consistency_check_prompt(world))
    return extract_json(raw)

# %%
# Run consistency check on world state
consistency_report = run_consistency_check(world)
print("CONSISTENCY CHECK")
pprint(consistency_report)
# Out:
# CONSISTENCY CHECK
# {'is_consistent': False,
#  'issues': ["Character Contradiction: Julian Thorne's character sheet states "
#             "'alibi_is_lie: false'. However, Clue 3 explicitly states that his "
#             'phone records contradict his claim of being on a private phone '
#             "call, AND 'no one saw him there'. The 'no one saw him there' part "
#             'strongly implies his presence on the secluded balcony (his '
#             'claimed location) is uncorroborated or even false, which would '
#             'make his alibi regarding his whereabouts a lie, and thus '
#             "'alibi_is_lie' should be true. This is a minor internal "
#             "contradiction between the character's definition and a clue's "
#             "description of his alibi's veracity.",
#             "Clue Utilization Anomaly: Clue 3 ('Security footage shows Julian "
#             'Thorne stepping onto a secluded balcony...phone records show no '
#             "outgoing calls... and no one saw him there') and Clue 6 ('Several "
#             'gala attendees recall witnessing a very public and heated '
#             'argument between Elias Thorne and his nephew, Julian Thorne, near '
#             "the study entrance...') are both marked with "
#             "'revealed_in_plot_point: -1'. This means these clues are never "
#             'actually revealed to Detective Inspector Sharma or utilized in '
#             'her investigation within the provided plot points. While not a '
#             'logical contradiction, it means these intended red herrings for '
#             "Julian Thorne do not play an active role in the detective's "
#             'journey, which might be a missed opportunity to misdirect the '
#             'detective.'],
#  'summary': 'The story plan is largely consistent and well-structured, with a '
#             'strong, logical progression of plot points, escalating tension, '
#             "and effective use of red herrings. The detective's path "
#             'successfully leads to the correct criminal and method. The '
#             'identified issues are minor regarding the precise definition of a '
#             "character's alibi status and the non-utilization of certain red "
#             "herring clues within the detective's plot, neither of which "
#             'fundamentally breaks the core logic or consistency of the '
#             'narrative.'}

# %%
# Functions for building narrative/prose from generated story world object
def build_narrative_assembly_prompt(world: StoryWorld) -> str:
    detective = next((c for c in world.characters if c.role == "detective"), None)

    characters_payload = [
        {
            "name": c.name,
            "role": c.role,
            "description": c.description,
            "motive": c.motive,
            "opportunity": c.opportunity,
            "alibi": c.alibi,
            "is_criminal": c.is_criminal
        }
        for c in world.characters
    ]

    clues_payload = [
        {
            "clue_id": cl.clue_id,
            "description": cl.description,
            "location": cl.location,
            "is_red_herring": cl.is_red_herring,
            "points_to": cl.points_to,
            "revealed_in_plot_point": cl.revealed_in_plot_point
        }
        for cl in world.clues
    ]

    plot_descriptions = [
        {
            "index": p.index,
            "title": p.title,
            "description": p.description,
            "action_taken": p.action_taken,
            "outcome": p.outcome,
            "obstacle": p.obstacle,
            "characters_involved": p.characters_involved,
            "clues_revealed": p.clues_revealed,
            "clues_used": p.clues_used
        }
        for p in sorted(world.plot_points, key=lambda x: x.index)
    ]

    payload = {
        "detective_name": detective.name if detective else "The detective",
        "crime_type": world.crime_details.crime_type if world.crime_details else "",
        "victim": world.crime_details.victim if world.crime_details else "",
        "location": world.crime_details.location if world.crime_details else "",
        "countdown_deadline": getattr(world, "countdown_deadline", ""),
        "countdown_consequence": getattr(world, "countdown_consequence", ""),
        "characters": characters_payload,
        "clues": clues_payload,
        "plot_points": plot_descriptions
    }

    return f"""
You are a skilled mystery novelist.

Write a complete mystery story based on the materials below.

Story materials:
{json.dumps(payload, indent=2)}

Instructions:
- Write a full, immersive narrative in the style of a mystery novel.
- Do NOT write a synopsis or summary.
- Expand the plot points into scenes with atmosphere, movement, reflection, and tension.
- Preserve the sequence of events and the underlying logic of the investigation.
- Use the characters consistently with their descriptions and roles.
- Weave clues naturally into the prose.
- Develop red herrings in a believable way.
- Maintain strong suspense throughout, with the countdown pressure growing more intense as the story progresses.
- The detective should gradually piece the truth together through observation, inference, and misdirection.
- Use polished, engaging prose and natural transitions.
- The ending should feel like a proper mystery revelation, with the detective identifying the true criminal in a satisfying way.
- A detailed and well-written story is better than a compressed one.
- Please keep it 1500-2000 words.

Literary style:
- Clear but literary prose
- Varied sentence structure
- Strong scene transitions
- Show, don’t just tell
- Dialogue should be used frequently and naturally throughout the story

Dialogue requirements:
- Include regular dialogue between characters (detective, suspects, witnesses)
- Conversations should drive the investigation forward
- Use dialogue to reveal clues, contradictions, and personality
- Avoid long stretches without dialogue
- Dialogue should feel natural, not overly formal or robotic
- Mix dialogue with action and internal thoughts

Do not:
- mention "plot point"
- mention "countdown mechanism"
- list clues explicitly
- write headings, bullet points, or outline labels

Output only the final story.
""".strip()


def assemble_final_narrative(world: StoryWorld) -> str:
    if len(world.plot_points) < 15:
        raise ValueError("Need at least 15 plot points before assembling final narrative.")

    raw = ask_llm(build_narrative_assembly_prompt(world))
    world.final_narrative = raw.strip()
    return world.final_narrative

# %%
# Runs final narrative assembly and prints output

final_story = assemble_final_narrative(world)
print(world.final_narrative)
# Out:
#
# Anya didn't hesitate. An urgent search warrant was secured for Dr. Evelyn Reed’s elegant residence and private clinic. While no direct evidence of the specific neurotoxin itself was found, suggesting a meticulous disposal, the search yielded other crucial links. In a discreet, ornate jewelry box, investigators discovered several hatpins identical in style to the murder weapon. One, however, stood out: its tip subtly filed down, perfectly matching the break on the recovered hatpin. And there, draped over a silk dressing gown, was a luxurious emerald-green silk scarf. Its fibers were a perfect match to the microscopic synthetic fiber found on Elias Thorne's lapel. The circumstantial web around Dr. Reed was tightening.
#
# But the Chief Medical Examiner remained unyielding. "Circumstantial, Inspector. I still need proof of the toxin *in his system*. We're less than eighteen hours from the scheduled procedure."
#
# Anya made a high-stakes, desperate move. Bypassing the Chief Medical Examiner, she immediately applied to the High Court for an emergency order. She presented her comprehensive case for murder: the hatpin, the matching set, the emerald scarf, the suspicious sedative, the faint puncture. She requested an immediate, mandatory forensic hold on Elias Thorne's body for a full, expanded toxicology screening.
#
# The High Court judge, after an intense emergency hearing, acknowledged the compelling circumstantial evidence but expressed severe reluctance to overrule the Chief Medical Examiner. "I will grant a final, non-renewable six-hour extension to the embalming deadline, Inspector. But you must produce unassailable, direct forensic proof of the neurotoxin *within Thorne's body* before it expires. Fail, and the embalming proceeds."
#
# Six hours. An almost impossible task. Anya immediately contacted Dr. Anya Petrova, a brilliant but notoriously private forensic toxicologist known for her expertise in rare compounds. Anya laid out the case, the specific neurotoxin, the crushing deadline. Dr. Petrova, recognizing the scientific challenge, agreed.
#
# Under immense pressure, Dr. Petrova, utilizing cutting-edge techniques, began her analysis. As the minutes bled away, she found it: a unique, highly unstable *metabolite* of the specific neurotoxin in a previously preserved tissue sample from Thorne. It was unequivocally there; the body had processed it.
#
# Anya and a visibly weary Dr. Petrova returned to the High Court. Dr. Petrova meticulously presented her findings, explaining the metabolite’s scientific significance. “It confirms, unequivocally, that the neurotoxin was present and processed by Mr. Thorne’s system.”
#
# The judge, though acknowledging Petrova's expertise, remained unconvinced. "A metabolite, Doctor, is a byproduct. I demanded proof of the neurotoxin itself. I will grant a *mere three-hour, non-renewable extension*. You may attempt a single, last-ditch, experimental mass spectrometry technique on Thorne's most viable remaining tissue sample. If *that* fails to detect any trace of the original neurotoxin, the embalming will proceed immediately."
#
# Three hours. The air in the toxicology lab crackled with desperate energy. Anya stood shoulder-to-shoulder with Dr. Petrova as the experimental mass spectrometry machinery sputtered to life. This was it. Their last chance. But just as the complex machine began its work, a critical, unforeseen software error halted the process. The experimental algorithm encountered a severe compatibility issue. Petrova and her team plunged into troubleshooting, but the problem was deep-seated, demanding a time-consuming reconfiguration. Precious minutes evaporated.
#
# Anya felt a cold dread begin to spread. “Dr. Petrova,” she said, her voice tight, “we don’t have time for perfection. A high-speed, compromised scan. Now. Even if it risks data integrity.”
#
# Under extreme duress, Petrova forced the spectrometer through a heavily abbreviated run. The system produced a highly unstable data stream showing erratic, almost imperceptible spikes that *could* be indicative of the neurotoxin, but the readings were too noisy, too inconsistent to be conclusive. A fragmented whisper, not a clear voice. Mere minutes remained.
#
# Anya’s mind raced, replaying every detail: the rare neurotoxin, the faint puncture, and Dr. Reed’s high-dosage sedative prescription. A desperate thought sparked. “Dr. Petrova! The sedative! What if the neurotoxin, interacting with that powerful sedative, created a unique, more stable chemical signature? Re-process the raw data. Filter for *that* specific interaction!”
#
# With only seconds melting away, Dr. Petrova plunged back into the noisy, ambiguous data. Her fingers flew across the keyboard, applying the new filter, the new algorithm. Then, a flicker. A faint but distinct and scientifically verifiable *molecular signature* of the neurotoxin-sedative interaction appeared on the screen. It wasn’t the neurotoxin itself, but undeniable proof that *both* were present and had reacted within Elias Thorne’s body.
#
# At that exact moment, the lab phone shrieked. A frantic voice on the other end. “Inspector! They’ve started! The embalming… it’s begun!”
#
# Anya didn't waste another second. "Petrova, print that report! We're moving!" Ignoring protocol, ignoring bureaucratic resistance, Anya and Dr. Petrova raced out of the lab, down the corridors, and tore towards the hospital morgue.
#
# Anya burst through the morgue doors. The sterile room was a horrifying tableau. Elias Thorne’s body lay on the table, a bewildered and indignant Chief Medical Examiner and his staff already several minutes into the embalming process. Hoses connected, fluids flowing.
#
# “Halt!” Anya roared, her voice echoing off the tiled walls. “Stop the procedure! Now!”
#
# The CME stared at her, furious. “Sharma! You’re out of line! The judge’s deadline expired!”
#
# “New evidence!” Dr. Petrova yelled, thrusting her tablet into the CME’s face, the molecular signature glowing starkly on the screen. “Undeniable proof of the neurotoxin’s presence and interaction!”
#
# The CME, initially furious, was visibly shaken by the undeniable scientific proof. He looked from the tablet to Anya’s unyielding gaze, then back to the hoses. With a defeated sigh, he ordered the procedure stopped.
#
# But the damage was done. Embalming fluid had already been partially introduced, the initial flushing begun. “The most crucial samples,” Dr. Petrova reported grimly, after a rapid assessment, “have been compromised. Diluted, chemically altered.” While the unique neurotoxin-sedative molecular signature was definitively present in the few minute, peripheral tissue samples she managed to salvage, proving the *original concentration* or the *direct, unaltered presence* of the raw neurotoxin beyond a shadow of a doubt in these chemically modified samples was an almost impossible forensic feat.
#
# Back in the High Court, Anya and Dr. Petrova presented the salvaged, but tainted, truth. Dr. Petrova meticulously detailed the molecular signature and the extent of the embalming’s irreversible impact. Anya, her voice resonating with grim determination, argued forcefully, “Despite the damage inflicted, Your Honor, this unequivocally proves murder. The evidence points to Dr. Evelyn Reed, who sought to silence Elias Thorne before he exposed her at the gala. We demand a permanent forensic hold and her immediate arrest.”
#
# The High Court judge, presented with the undeniable, albeit chemically altered, proof of the neurotoxin’s presence and interaction within Thorne’s body, ruled that there was sufficient evidence to prevent further embalming and to issue an immediate arrest warrant for Dr. Evelyn Reed.
#
# Dr. Reed was apprehended, calm and composed even as the handcuffs clicked into place. She denied everything, her eyes cool and unyielding. The embalming was permanently halted, the remaining evidence secured, but Anya knew the true battle was yet to come. Dr. Reed’s defense would relentlessly attack the compromised nature of the samples, casting doubt on the lethal dosage and the overall integrity of the evidence. Justice would be a hard-won fight, but Elias Thorne, at least, would no longer rest under the lie of a natural death. The truth, however tainted, had finally been exhumed.
