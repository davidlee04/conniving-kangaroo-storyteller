# %%
# !pip install -q -U google-genai
# Out:
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyD6xB32wGetW1Aj7DRXWq6J4nQ0UhNW8K4"

# %%
from google import genai

client = genai.Client()
MODEL = "gemini-2.5-flash"

# Sanity check
response = client.models.generate_content(model=MODEL, contents="Say: ready")
print("LLM status:", response.text.strip())
# Out:
# LLM status: Ready

# %%
def ask_llm(prompt: str):
    response = client.models.generate_content(
        model=MODEL,
        contents=prompt
    )
    return response.text.strip()

# %%
def extract_json(text: str):
    """
    Extract the first JSON object or array from model output.
    Handles markdown code fences like ```json ... ```.
    """
    # Remove markdown fences if present
    fenced = re.search(r"```(?:json)?\s*(.*?)```", text, re.DOTALL)
    if fenced:
        text = fenced.group(1).strip()

    # Try full parse first
    try:
        return json.loads(text)
    except json.JSONDecodeError:
        pass

    # Fallback: find first JSON object or array
    match = re.search(r"(\{.*\}|\[.*\])", text, re.DOTALL)
    if match:
        return json.loads(match.group(1))

    raise ValueError(f"No JSON found in LLM response:\n{text}")

# %% [markdown]
# ## Section 1: Data Structures
# Defines all dataclasses used to store story state. Sections 2 and 3 (story generation and compilation) will populate these.

# %% [markdown]
# | Class | Role | Function |
# |---|---|---|
# | `CrimeDetails` | The hidden truth | Keeps the ground-truth crime facts isolated so the LLM can never accidentally leak them into suspect dialogue or clue descriptions |
# | `Character` | Any person in the story | Stores means/motive/opportunity explicitly so the meta-controller can check MMO coverage without re-querying the LLM |
# | `Clue` | A piece of evidence | `is_red_herring` and `discovered` flags let the controller track what the detective *can* know vs. what *really* points to the criminal |
# | `PlotPoint` | One story beat | `suspense_score` on each beat makes the rising tension arc a measurable, enforceable property rather than a vague stylistic goal |
# | `StoryWorld` | Global state container | A single object passed by reference into every generation function — any LLM call can read current state via `summary_so_far()` without duplicating data |

# %%
import json
import re
from dataclasses import dataclass, field
from typing import List, Optional
from pprint import pprint


@dataclass
class Character:
    """A character in the story: detective, suspect, criminal, or witness."""
    name: str
    role: str                        # 'detective' | 'suspect' | 'criminal' | 'witness'
    description: str
    means: str                       # capability to commit the crime
    motive: str                      # reason to commit the crime
    opportunity: str                 # could they have been at the scene?
    alibi: str
    alibi_is_lie: bool = False
    is_criminal: bool = False
    eliminated: bool = False         # True once the detective rules them out
    notes: List[str] = field(default_factory=list)


@dataclass
class Clue:
    """A piece of evidence or information discoverable by the detective."""
    clue_id: int
    description: str
    location: str
    discovered: bool = False
    is_red_herring: bool = False
    points_to: str = ""              # character or event this implicates
    revealed_in_plot_point: int = -1


@dataclass
class PlotPoint:
    """One story beat that advances the plot."""
    index: int
    title: str
    description: str
    action_taken: str
    outcome: str
    obstacle: str
    suspense_score: float            # 0.0 (low tension) → 1.0 (maximum)
    characters_involved: List[str] = field(default_factory=list)
    clues_revealed: List[int] = field(default_factory=list)
    clues_used: List[int] = field(default_factory=list)


@dataclass
class CrimeDetails:
    """The hidden backstory: what really happened before the detective arrives."""
    crime_type: str
    victim: str
    location: str
    time_of_crime: str
    method: str
    criminal_name: str
    criminal_motive: str
    criminal_means: str
    key_evidence_hidden: List[str] = field(default_factory=list)
    backstory_summary: str = ""


@dataclass
class StoryWorld:
    """Master container for all story state."""
    crime_details: Optional[CrimeDetails] = None
    characters: List[Character] = field(default_factory=list)
    clues: List[Clue] = field(default_factory=list)
    plot_points: List[PlotPoint] = field(default_factory=list)
    countdown_deadline: str = ""
    countdown_consequence: str = ""
    final_narrative: str = ""

    def get_character(self, name: str) -> Optional[Character]:
        for c in self.characters:
            if c.name.lower() == name.lower():
                return c
        return None

    def get_clue(self, clue_id: int) -> Optional[Clue]:
        for cl in self.clues:
            if cl.clue_id == clue_id:
                return cl
        return None

    def discovered_clues(self) -> List[Clue]:
        return [cl for cl in self.clues if cl.discovered]

    def active_suspects(self) -> List[Character]:
        return [c for c in self.characters if c.role in ('suspect', 'criminal') and not c.eliminated]

    def summary_so_far(self) -> str:
        """Brief text digest of current story state, used as context in LLM prompts."""
        lines = []
        if self.crime_details:
            cd = self.crime_details
            lines.append(f"CRIME: {cd.crime_type} of {cd.victim} at {cd.location} ({cd.time_of_crime}).")
        lines.append(f"ACTIVE SUSPECTS: {[c.name for c in self.active_suspects()]}")
        lines.append(f"CLUES FOUND: {[cl.description[:40] for cl in self.discovered_clues()]}")
        if self.plot_points:
            last = self.plot_points[-1]
            lines.append(f"LAST PLOT POINT ({last.index}): {last.title} — {last.outcome}")
        return "\n".join(lines)


print("Data structures defined.")
# Out:
# Data structures defined.

# %%
# Checkpoint 1: confirm StoryWorld initializes correctly
world = StoryWorld()
print("StoryWorld initialized:", world)
# Out:
# StoryWorld initialized: StoryWorld(crime_details=None, characters=[], clues=[], plot_points=[], countdown_deadline='', countdown_consequence='', final_narrative='')

# %%
def build_crime_details_prompt() -> str:
    return """
You are helping build the hidden ground-truth backstory for a gala murder crime mystery.

Generate a single crime scenario for a detective story.

Requirements:
- The crime must be a serious crime suitable for a mystery story.
- It must be solvable, but not obvious.
- The crime must support multiple plausible suspects later.
- The criminal's motive, means, and opportunity must all make sense together.
- The method of the crime must leave behind evidence that can later be discovered.
- The crime should not rely on supernatural elements or impossible coincidences.

Return ONLY valid JSON with exactly these keys:
{
  "crime_type": "...",
  "victim": "...",
  "location": "...",
  "time_of_crime": "...",
  "method": "...",
  "criminal_name": "...",
  "criminal_motive": "...",
  "criminal_means": "...",
  "key_evidence_hidden": ["...", "...", "..."],
  "backstory_summary": "..."
}

Field guidance:
- crime_type: e.g. "murder", "blackmail", "kidnapping", "art theft" (in this case, it will be "murder")
- victim: full name and a few identifying words
- location: specific and story-friendly
- time_of_crime: specific enough to anchor a timeline
- method: how the crime was carried out
- criminal_name: full name
- criminal_motive: concrete and personal
- criminal_means: how they were capable of doing it
- key_evidence_hidden: 3 to 5 important hidden evidence items
- backstory_summary: 1 paragraph summary of what truly happened before the detective starts investigating

Important:
- The criminal should not be the most obvious suspect.
- The motive should be meaningful, not generic.
- The evidence should connect naturally to the crime method.
- Return JSON only. No explanation.
""".strip()

# %%
def generate_crime_details() -> CrimeDetails:
    prompt = build_crime_details_prompt()
    raw = ask_llm(prompt)
    data = extract_json(raw)

    crime = CrimeDetails(
        crime_type=data["crime_type"],
        victim=data["victim"],
        location=data["location"],
        time_of_crime=data["time_of_crime"],
        method=data["method"],
        criminal_name=data["criminal_name"],
        criminal_motive=data["criminal_motive"],
        criminal_means=data["criminal_means"],
        key_evidence_hidden=data.get("key_evidence_hidden", []),
        backstory_summary=data.get("backstory_summary", "")
    )
    return crime

# %%
world.crime_details = generate_crime_details()

pprint(world.crime_details)
print()
print(world.crime_details.backstory_summary)
# Out:
# CrimeDetails(crime_type='murder',
#              victim='Julian Thorne, renowned philanthropic tech mogul and host '
#                     'of the gala',
#              location="The opulent 'Starlight Ballroom' at the Grand Regent "
#                       "Hotel, during the annual 'Thorne Foundation Charity "
#                       "Gala'",
#              time_of_crime="Approximately 10:45 PM, just after Julian Thorne's "
#                            'keynote address, during the main cocktail hour',
#              method='Julian Thorne was poisoned with a fast-acting, odorless, '
#                     'and tasteless neurotoxin. The poison was applied to a '
#                     'specific, unique brand of herbal throat lozenges Thorne '
#                     'habitually used before public speaking. The criminal '
#                     "replaced a few genuine lozenges in Thorne's personal tin, "
#                     'kept in his private study adjoining the ballroom, with '
#                     'doctored ones. Thorne consumed one just before his '
#                     'keynote address, but the effects were delayed by a few '
#                     'minutes, manifesting after he stepped down from the '
#                     'podium.',
#              criminal_name='Evelyn Reed',
#              criminal_motive='Julian Thorne had discovered a past financial '
#                              "impropriety committed by Evelyn Reed's ailing "
#                              'younger brother, a secret Evelyn had '
#                              'meticulously covered up for years to protect '
#                              'him. Thorne, known for his ruthless business '
#                              'practices despite his public philanthropy, began '
#                              'secretly blackmailing Evelyn, demanding she '
#                              'manipulate financial records for his personal '
#                              'gain, threatening to expose her brother if she '
#                              "refused. Evelyn saw Thorne's death as the only "
#                              'way to free herself and her brother from his '
#                              'control.',
#              criminal_means="Evelyn, as Thorne's personal assistant, had "
#                             'intimate knowledge of his routines and '
#                             'unrestricted access to his private study '
#                             'connected to the ballroom. She spent months '
#                             'researching undetectable poisons, eventually '
#                             'synthesizing a potent neurotoxin from common, but '
#                             'specific, chemical precursors she sourced '
#                             'discreetly. Her meticulous nature allowed her to '
#                             'precisely apply the toxin to the lozenges without '
#                             'leaving obvious traces.',
#              key_evidence_hidden=['A partially dissolved, chemically unusual '
#                                   "lozenge found in a waste bin in Thorne's "
#                                   'private study, near his usual lozenge tin.',
#                                   'A small, coded notebook detailing chemical '
#                                   'compounds and their effects, hidden inside '
#                                   "Evelyn Reed's personal safe-deposit box at "
#                                   'her bank, disguised as a mundane personal '
#                                   'diary.',
#                                   "A single, encrypted data file on Thorne's "
#                                   'personal, highly secured tablet, '
#                                   'referencing a financial transaction tied to '
#                                   "Evelyn's brother, accessible only with a "
#                                   'specific decryption key.',
#                                   'A discarded, torn receipt for specialized '
#                                   'laboratory glassware and specific chemical '
#                                   'reagents, found at the bottom of a rarely '
#                                   "used recycling bin in Evelyn's apartment "
#                                   "building's basement, dated several months "
#                                   'prior.'],
#              backstory_summary='Julian Thorne, a publicly lauded but privately '
#                                'ruthless tech mogul, discovered a long-buried '
#                                "financial fraud committed by Evelyn Reed's "
#                                'ailing brother. Using this as leverage, Thorne '
#                                'began blackmailing Evelyn, his personal '
#                                'assistant, forcing her to manipulate company '
#                                'finances for his benefit. Desperate to protect '
#                                "her brother and escape Thorne's control, "
#                                'Evelyn meticulously planned his murder. '
#                                'Knowing his habit of using specific throat '
#                                'lozenges before public speaking, she '
#                                'synthesized a neurotoxin and replaced some of '
#                                'the lozenges in his private tin with poisoned '
#                                'ones. Thorne consumed one just before his '
#                                'keynote address at the gala, and the delayed '
#                                'effects led to his collapse and death shortly '
#                                'after stepping off the stage.')
#
# Julian Thorne, a publicly lauded but privately ruthless tech mogul, discovered a long-buried financial fraud committed by Evelyn Reed's ailing brother. Using this as leverage, Thorne began blackmailing Evelyn, his personal assistant, forcing her to manipulate company finances for his benefit. Desperate to protect her brother and escape Thorne's control, Evelyn meticulously planned his murder. Knowing his habit of using specific throat lozenges before public speaking, she synthesized a neurotoxin and replaced some of the lozenges in his private tin with poisoned ones. Thorne consumed one just before his keynote address at the gala, and the delayed effects led to his collapse and death shortly after stepping off the stage.

# %%
def build_characters_prompt(crime: CrimeDetails) -> str:
    crime_payload = {
        "crime_type": crime.crime_type,
        "victim": crime.victim,
        "location": crime.location,
        "time_of_crime": crime.time_of_crime,
        "method": crime.method,
        "criminal_name": crime.criminal_name,
        "criminal_motive": crime.criminal_motive,
        "criminal_means": crime.criminal_means,
        "key_evidence_hidden": crime.key_evidence_hidden,
        "backstory_summary": crime.backstory_summary,
    }

    return f"""
You are generating the cast of characters for a crime mystery.

The hidden ground-truth crime is:
{json.dumps(crime_payload, indent=2)}

Create:
- 1 detective
- 5 suspects who are NOT the criminal
- 1 criminal character whose name MUST exactly match the criminal_name above

Return ONLY valid JSON with exactly this structure:
{{
  "detective": {{
    "name": "...",
    "role": "detective",
    "description": "...",
    "means": "N/A",
    "motive": "solve the case",
    "opportunity": "arrives after the crime to investigate",
    "alibi": "N/A"
  }},
  "criminal": {{
    "name": "...",
    "role": "criminal",
    "description": "...",
    "means": "...",
    "motive": "...",
    "opportunity": "...",
    "alibi": "...",
    "alibi_is_lie": true
  }},
  "suspects": [
    {{
      "name": "...",
      "role": "suspect",
      "description": "...",
      "means": "...",
      "motive": "...",
      "opportunity": "...",
      "alibi": "...",
      "alibi_is_lie": false
    }}
  ]
}}

Requirements:
- The criminal name must exactly match the given criminal_name.
- There must be exactly 5 suspects in the suspects list.
- Every suspect must have plausible means, motive, and opportunity.
- At least 2 suspects should look strongly suspicious at first.
- At least 2 innocent suspects should have a false or misleading alibi.
- The criminal should not be the most obvious suspect.
- The detective should feel capable and specific, not generic.
- Suspects should have relationships to the victim, location, or circumstances of the crime.
- Keep all details realistic and internally consistent.

Return JSON only.
""".strip()


def generate_characters(world: StoryWorld) -> List[Character]:
    if not world.crime_details:
        raise ValueError("world.crime_details must exist before generating characters.")

    raw = ask_llm(build_characters_prompt(world.crime_details))
    data = extract_json(raw)

    characters = []

    detective_data = data["detective"]
    detective = Character(
        name=detective_data["name"],
        role="detective",
        description=detective_data["description"],
        means=detective_data.get("means", "N/A"),
        motive=detective_data.get("motive", "solve the case"),
        opportunity=detective_data.get("opportunity", "arrives after the crime to investigate"),
        alibi=detective_data.get("alibi", "N/A"),
        alibi_is_lie=False,
        is_criminal=False,
        eliminated=False,
        notes=[]
    )
    characters.append(detective)

    criminal_data = data["criminal"]
    criminal = Character(
        name=criminal_data["name"],
        role="criminal",
        description=criminal_data["description"],
        means=criminal_data["means"],
        motive=criminal_data["motive"],
        opportunity=criminal_data["opportunity"],
        alibi=criminal_data["alibi"],
        alibi_is_lie=criminal_data.get("alibi_is_lie", True),
        is_criminal=True,
        eliminated=False,
        notes=[]
    )
    characters.append(criminal)

    for suspect_data in data["suspects"]:
        suspect = Character(
            name=suspect_data["name"],
            role="suspect",
            description=suspect_data["description"],
            means=suspect_data["means"],
            motive=suspect_data["motive"],
            opportunity=suspect_data["opportunity"],
            alibi=suspect_data["alibi"],
            alibi_is_lie=suspect_data.get("alibi_is_lie", False),
            is_criminal=False,
            eliminated=False,
            notes=[]
        )
        characters.append(suspect)

    return characters

    
def build_character_validation_prompt(world: StoryWorld, characters: List[Character]) -> str:
    crime = world.crime_details
    if not crime:
        raise ValueError("No crime details in world.")

    payload = {
        "crime_details": {
            "crime_type": crime.crime_type,
            "victim": crime.victim,
            "location": crime.location,
            "time_of_crime": crime.time_of_crime,
            "method": crime.method,
            "criminal_name": crime.criminal_name,
            "criminal_motive": crime.criminal_motive,
            "criminal_means": crime.criminal_means,
            "backstory_summary": crime.backstory_summary,
        },
        "characters": [
            {
                "name": c.name,
                "role": c.role,
                "description": c.description,
                "means": c.means,
                "motive": c.motive,
                "opportunity": c.opportunity,
                "alibi": c.alibi,
                "alibi_is_lie": c.alibi_is_lie,
                "is_criminal": c.is_criminal,
            }
            for c in characters
        ]
    }

    return f"""
You are validating the character set for a crime mystery.

Data:
{json.dumps(payload, indent=2)}

Check:
1. Is there exactly 1 detective?
2. Is there exactly 1 criminal and does their name match the hidden criminal_name?
3. Are there exactly 5 non-criminal suspects?
4. Does every suspect have plausible means, motive, or opportunity?
5. Are at least 2 suspects genuinely suspicious at first?
6. Are the characters distinct from one another?
7. Are there any contradictions with the crime setup?

Return ONLY valid JSON:
{{
  "is_valid": true,
  "issues": ["..."],
  "suggested_fixes": ["..."]
}}
""".strip()


def validate_characters(world: StoryWorld, characters: List[Character]) -> dict:
    raw = ask_llm(build_character_validation_prompt(world, characters))
    return extract_json(raw)

# %%
def build_clues_prompt(world: StoryWorld) -> str:
    if not world.crime_details:
        raise ValueError("world.crime_details must exist before generating clues.")
    if not world.characters:
        raise ValueError("world.characters must exist before generating clues.")

    crime = world.crime_details
    character_payload = [
        {
            "name": c.name,
            "role": c.role,
            "description": c.description,
            "means": c.means,
            "motive": c.motive,
            "opportunity": c.opportunity,
            "alibi": c.alibi,
            "alibi_is_lie": c.alibi_is_lie,
            "is_criminal": c.is_criminal,
        }
        for c in world.characters
    ]

    crime_payload = {
        "crime_type": crime.crime_type,
        "victim": crime.victim,
        "location": crime.location,
        "time_of_crime": crime.time_of_crime,
        "method": crime.method,
        "criminal_name": crime.criminal_name,
        "criminal_motive": crime.criminal_motive,
        "criminal_means": crime.criminal_means,
        "key_evidence_hidden": crime.key_evidence_hidden,
        "backstory_summary": crime.backstory_summary,
    }

    return f"""
You are generating discoverable clues for a crime mystery.

Hidden crime details:
{json.dumps(crime_payload, indent=2)}

Character list:
{json.dumps(character_payload, indent=2)}

Generate 8 clues.

Return ONLY valid JSON with exactly this structure:
{{
  "clues": [
    {{
      "clue_id": 1,
      "description": "...",
      "location": "...",
      "is_red_herring": false,
      "points_to": "...",
      "why_it_matters": "..."
    }}
  ]
}}

Requirements:
- Generate exactly 8 clues.
- Clues must follow naturally from the true crime and the characters.
- At least 2 clues must initially point toward innocent suspects.
- At least 2 clues must meaningfully connect to the real criminal.
- At least 1 clue should relate to a false alibi.
- At least 1 clue should be ambiguous until later interpretation.
- The clues should not instantly solve the crime when seen alone.
- "points_to" should name a character or a specific event/fact.
- clue_id values must be 1 through 8.

Return JSON only.
""".strip()


def generate_clues(world: StoryWorld) -> List[Clue]:
    raw = ask_llm(build_clues_prompt(world))
    data = extract_json(raw)
    
    clues = []
    for clue_data in data["clues"]:
        clue = Clue(
            clue_id=clue_data["clue_id"],
            description=clue_data["description"],
            location=clue_data["location"],
            discovered=False,
            is_red_herring=clue_data.get("is_red_herring", False),
            points_to=clue_data.get("points_to", ""),
            revealed_in_plot_point=-1
        )
        clues.append(clue)
    
    return clues


def build_clue_validation_prompt(world: StoryWorld, clues: List[Clue]) -> str:
    crime = world.crime_details
    if not crime:
        raise ValueError("No crime details in world.")

    payload = {
        "crime_details": {
            "crime_type": crime.crime_type,
            "victim": crime.victim,
            "location": crime.location,
            "time_of_crime": crime.time_of_crime,
            "method": crime.method,
            "criminal_name": crime.criminal_name,
            "criminal_motive": crime.criminal_motive,
            "criminal_means": crime.criminal_means,
            "backstory_summary": crime.backstory_summary,
        },
        "characters": [
            {
                "name": c.name,
                "role": c.role,
                "is_criminal": c.is_criminal,
                "alibi": c.alibi,
                "alibi_is_lie": c.alibi_is_lie,
            }
            for c in world.characters
        ],
        "clues": [
            {
                "clue_id": cl.clue_id,
                "description": cl.description,
                "location": cl.location,
                "is_red_herring": cl.is_red_herring,
                "points_to": cl.points_to,
            }
            for cl in clues
        ]
    }

    return f"""
You are validating the clue set for a crime mystery.

Data:
{json.dumps(payload, indent=2)}

Check:
1. Are there exactly 8 clues?
2. Do the clues arise naturally from the crime and character setup?
3. Do at least 2 clues point toward innocent suspects at first?
4. Do at least 2 clues connect meaningfully to the real criminal?
5. Is the mystery neither trivial nor impossible?
6. Are any clues redundant, contradictory, or disconnected?

Return ONLY valid JSON:
{{
  "is_valid": true,
  "issues": ["..."],
  "suggested_fixes": ["..."]
}}
""".strip()


def validate_clues(world: StoryWorld, clues: List[Clue]) -> dict:
    raw = ask_llm(build_clue_validation_prompt(world, clues))
    return extract_json(raw)

# %%
def build_countdown_prompt(world: StoryWorld) -> str:
    if not world.crime_details:
        raise ValueError("world.crime_details must exist first")

    crime = world.crime_details

    payload = {
        "crime_type": crime.crime_type,
        "victim": crime.victim,
        "location": crime.location,
        "time_of_crime": crime.time_of_crime,
        "method": crime.method,
        "criminal_name": crime.criminal_name,
        "criminal_motive": crime.criminal_motive,
        "backstory_summary": crime.backstory_summary,
    }

    return f"""
You are designing a countdown mechanism for a suspenseful detective story.

The countdown must:
- Be concrete and time-bound
- Be directly connected to the crime or investigation
- Create urgency that increases over time
- Make failure meaningful and irreversible

Crime context:
{json.dumps(payload, indent=2)}

Generate:
1. A specific countdown deadline (what event is approaching?)
2. A specific consequence if the detective fails before the deadline

Constraints:
- The deadline should feel natural to the scenario (not arbitrary)
- The consequence must be severe and story-relevant
- The consequence should make the truth harder or impossible to recover
- Avoid vague phrasing like "things get worse"

Examples of good countdowns:
- "By sunrise, the crime scene will be destroyed by the incoming storm."
- "In 24 hours, the prosecutor will formally charge the wrong suspect."
- "The suspect is scheduled to leave the country tonight."
- "A building demolition will erase crucial evidence."

Do not copy these exactly. Generate a new one specific to the crime.

Return ONLY valid JSON:
{{
  "countdown_deadline": "...",
  "countdown_consequence": "..."
}}
""".strip()


def generate_countdown(world: StoryWorld) -> StoryWorld:
    raw = ask_llm(build_countdown_prompt(world))
    data = extract_json(raw)

    world.countdown_deadline = data["countdown_deadline"]
    world.countdown_consequence = data["countdown_consequence"]

    return world

# %%
def populate_story_world(world: StoryWorld) -> StoryWorld:
    if not world.crime_details:
        raise ValueError("Generate crime details first.")

    characters = generate_characters(world)
    char_validation = validate_characters(world, characters)
    if not char_validation["is_valid"]:
        print("Invalid characters -- try again")
        pprint(char_validation)

    world.characters = characters

    clues = generate_clues(world)
    clue_validation = validate_clues(world, clues)
    if not clue_validation["is_valid"]:
        print("Invalid clues -- try again")
        pprint(clue_validation)

    world.clues = clues

    world = generate_countdown(world)
    return world

# %%
def print_characters(world: StoryWorld):
    print("\nCHARACTERS")
    print("=" * 60)
    for c in world.characters:
        print(f"Name: {c.name}")
        print(f"Role: {c.role}")
        print(f"Description: {c.description}")
        print(f"Means: {c.means}")
        print(f"Motive: {c.motive}")
        print(f"Opportunity: {c.opportunity}")
        print(f"Alibi: {c.alibi}")
        print(f"Alibi is lie: {c.alibi_is_lie}")
        print(f"Is criminal: {c.is_criminal}")
        print("-" * 60)


def print_clues(world: StoryWorld):
    print("\nCLUES")
    print("=" * 60)
    for cl in sorted(world.clues, key=lambda x: x.clue_id):
        print(f"Clue #{cl.clue_id}")
        print(f"Description: {cl.description}")
        print(f"Location: {cl.location}")
        print(f"Points to: {cl.points_to}")
        print(f"Red herring: {cl.is_red_herring}")
        print("-" * 60)


def print_countdown(world: StoryWorld):
    print("\nCOUNTDOWN SETUP")
    print("=" * 60)
    print(f"Deadline: {world.countdown_deadline}")
    print(f"Consequence: {world.countdown_consequence}")

# %%
world = populate_story_world(world)

print_characters(world)
print_clues(world)
print_countdown(world)
# Out:
# COUNTDOWN SETUP
# ============================================================
# Deadline: By 4:00 AM, Evelyn Reed, as Julian Thorne's highly trusted personal assistant, will execute a remote command to initiate a comprehensive, irreversible data purge on Julian Thorne's private, encrypted servers. These servers contain all the blackmail material Thorne held over her, including damning evidence of her brother's past financial impropriety and the detailed records of Evelyn's own forced financial manipulations.
# Consequence: All digital evidence proving Thorne's elaborate blackmail scheme—including encrypted communications, financial logs of Evelyn's forced manipulations, and Thorne's original documentation of her brother's hidden impropriety—will be permanently erased. This will render Evelyn's crucial motive for the murder impossible to substantiate, making her appear as a calculating, cold-blooded killer rather than a desperate protector, and irrevocably obscuring the full, complex truth behind Thorne's ruthless nature and her desperate act.
#
# CHARACTERS
# ============================================================
# Name: Detective Isabella "Izzy" Rossi
# Role: detective
# Description: A sharp, intuitive lead detective from the city's homicide unit, known for her unconventional thinking and ability to read subtle cues. With a background in forensic psychology, she often focuses on the 'why' behind the crime, meticulously dissecting motives and relationships. She's not easily swayed by public personas or initial impressions, always looking for the hidden currents beneath the surface.
# Means: N/A
# Motive: solve the case
# Opportunity: arrives after the crime to investigate
# Alibi: N/A
# Alibi is lie: False
# Is criminal: False
# ------------------------------------------------------------
# Name: Evelyn Reed
# Role: criminal
# Description: Julian Thorne's seemingly indispensable personal assistant. Meticulous, intelligent, and outwardly composed, she maintains a quiet, efficient demeanor that masks a fierce protectiveness towards her ailing younger brother. She appears utterly professional, almost invisible, in her devotion to Thorne, making her an unlikely suspect for many.
# Means: As Thorne's personal assistant, she possessed unparalleled access to his private study adjoining the ballroom, intimate knowledge of his daily routines, and a keen awareness of his habits, including his preference for specific herbal throat lozenges. Her meticulous nature, combined with months of discreet research, allowed her to synthesize a potent neurotoxin from common chemical precursors, which she precisely applied to a few genuine lozenges in Thorne's personal tin without leaving obvious traces.
# Motive: Driven by desperation, Evelyn sought to free herself and her ailing younger brother from Julian Thorne's ruthless blackmail. Thorne had discovered her brother's past financial impropriety and was forcing Evelyn to manipulate company financial records, threatening to expose her brother if she refused. Thorne's death was her only perceived escape from his control and the only way to safeguard her brother's future.
# Opportunity: Evelyn was present at the gala, performing her duties as Thorne's assistant. Her role granted her legitimate, unquestioned access to Thorne's private study both before and during the event. She knew Thorne would use the lozenges just before his keynote address, giving her a precise window to ensure the poisoned lozenges were consumed. She could have easily slipped into the study under the guise of arranging notes or checking Thorne's schedule, replacing the lozenges minutes before he entered to prepare for his speech.
# Alibi: Evelyn claims she was coordinating with the catering staff in the main kitchen area, overseeing the preparation of the late-night dessert course, during the exact time Thorne would have been in his study preparing for his speech. A chef's assistant can partially corroborate her presence, but not her precise location for every single minute.
# Alibi is lie: True
# Is criminal: True
# ------------------------------------------------------------
# Name: Victor Sterling
# Role: suspect
# Description: A cutthroat tech magnate and CEO of a rival company. Julian Thorne recently orchestrated a hostile takeover of a startup Sterling was aggressively pursuing, costing Sterling hundreds of millions and publicly humiliating him. He maintains a veneer of cordiality but harbors intense resentment.
# Means: As a prominent guest, Sterling had a private meeting with Thorne scheduled earlier in the evening in Thorne's study, giving him brief access to the room and knowledge of Thorne's habits. His vast wealth means he could easily acquire or commission unique substances if he chose, though his method would likely be less subtle than Evelyn's.
# Motive: Revenge for financial ruin and public humiliation. Thorne’s recent business maneuver directly impacted Sterling’s reputation and bottom line, fueling a burning desire to see Thorne suffer.
# Opportunity: Sterling was at the gala throughout the evening. He could have slipped into Thorne's private study, either during his scheduled meeting or under the guise of a 'quick word' just before the keynote, when the room would be momentarily empty as Thorne prepared.
# Alibi: Sterling claims he was engaged in a lengthy discussion with a group of investors and a potential new client in the main ballroom from 10:00 PM onwards, making him highly visible. However, one of the investors recalls him stepping away briefly, excusing himself to make a 'confidential call' just before Thorne went on stage.
# Alibi is lie: False
# Is criminal: False
# ------------------------------------------------------------
# Name: Dr. Eleanor Vance
# Role: suspect
# Description: Brilliant but disgraced former CTO of Thorne's company. Julian Thorne publicly fired her a year ago, blaming her for a massive data breach that nearly crippled the company, though many in the industry suspected Thorne himself engineered the scandal to consolidate power and remove a potential rival.
# Means: As a former CTO with a background in advanced computer science and a minor in biochemistry, Dr. Vance possesses the intellectual capacity and scientific knowledge to understand complex chemical compounds. Her past role might have also given her residual access codes or connections to hotel staff she could exploit for entry.
# Motive: Vengeance for her ruined career, tarnished reputation, and the public humiliation Thorne inflicted. She also believes Thorne betrayed the company's ethical standards and wanted to expose his true nature.
# Opportunity: Dr. Vance was not officially invited but bought a last-minute ticket, slipping in unnoticed by some of the high-profile guests. She was seen near the private study area earlier in the evening, claiming she was 'looking for a quieter restroom' away from the main crowds. This gave her proximity and an excuse.
# Alibi: Dr. Vance states she spent the critical time period in the hotel's secluded rooftop garden terrace, seeking fresh air and solitude, and therefore saw no one. She has no witnesses to corroborate her alibi.
# Alibi is lie: False
# Is criminal: False
# ------------------------------------------------------------
# Name: Marcus Thorne
# Role: suspect
# Description: Julian Thorne's estranged cousin and the meticulous, quietly resentful manager of the Thorne Foundation. He deeply believes in the foundation's original philanthropic mission and despises Julian's use of it for personal branding and tax evasion. He recently learned Julian was planning to replace him.
# Means: As the foundation manager, Marcus had legitimate, unquestioned access to Julian's private study, often needing to review documents or discuss last-minute gala details. He was intimately familiar with Julian's routines and habits, including his personal items in the study.
# Motive: Protecting the foundation's integrity, deep personal resentment towards Julian's superficiality and exploitation of their shared family name, and fear of being replaced. Julian's death would give Marcus full control over the foundation's direction.
# Opportunity: Marcus was constantly moving between the ballroom, Julian's study, and the back offices, coordinating the gala. He had several opportunities to be alone in the study, particularly during the busy pre-speech rush when attention was elsewhere.
# Alibi: Marcus claims he was reviewing donor lists in the back office's data room during the critical minutes before Julian's speech. However, a junior assistant reported seeing Marcus exiting the study just minutes before Julian entered it to prepare for his keynote.
# Alibi is lie: False
# Is criminal: False
# ------------------------------------------------------------
# Name: Lady Isabella Montgomery
# Role: suspect
# Description: A prominent socialite, major donor to the Thorne Foundation, and Julian's former clandestine lover. Julian recently ended their affair abruptly, threatening to expose a sensitive financial scandal involving her family's historic estate if she didn't comply with his demands to siphon funds from the foundation.
# Means: As a major donor and Julian's former lover, Isabella held enough influence and familiarity to request a 'private word' with Julian in his study, or simply slip in unnoticed during the gala's commotion. Her vast network could provide access to unusual substances if she desired.
# Motive: Revenge for being discarded and desperate to protect her family's centuries-old reputation from Julian's blackmail, which would have ruined her and her loved ones.
# Opportunity: Lady Montgomery was seen having a heated, whispered conversation with Julian earlier in the evening. She could have easily requested or demanded a private chat in his study during the gala, or used her familiarity with the layout to gain access.
# Alibi: Lady Montgomery maintains she was in the ladies' lounge, touching up her makeup and making a series of calls, throughout the critical period. However, a diligent hotel maid reported seeing her leave the general vicinity of the private study wing shortly after Julian began his speech, looking flustered.
# Alibi is lie: False
# Is criminal: False
# ------------------------------------------------------------
# Name: Commander David Miller
# Role: suspect
# Description: The stoic, ex-military Head of Security for the Grand Regent Hotel. Known for his strict adherence to protocol and unwavering loyalty to the hotel's reputation. Julian Thorne often clashed with him, viewing his security arrangements as excessive and a hindrance to his 'celebrity' status.
# Means: As Head of Security, Commander Miller possesses unrestricted access to all areas of the hotel, including Julian's private study, and could easily bypass any internal security measures. His military background could also imply knowledge of various harmful substances and their applications.
# Motive: Thorne's constant disregard for security protocols put the hotel's guests at risk and directly undermined Miller's authority and professional pride. Thorne was also threatening to take his lucrative business elsewhere if Miller didn't relax his rules, which would be a significant professional blow.
# Opportunity: Miller was constantly patrolling the gala, including the private areas, ensuring no unauthorized access. He could have easily slipped into the study when it was momentarily empty, under the guise of a routine security check.
# Alibi: Commander Miller claims he was in the main security office, reviewing CCTV footage of the ballroom during the critical time Thorne was in his study. However, the system experienced a brief, unexplained 'glitch' that created a blind spot on one crucial camera feed for approximately three minutes, precisely when he might have moved.
# Alibi is lie: False
# Is criminal: False
# ------------------------------------------------------------
#
# CLUES
# ============================================================
# Clue #1
# Description: A partially dissolved, chemically unusual herbal throat lozenge, distinct from Thorne's usual brand, is found in a waste bin in Julian Thorne's private study, near his personal lozenge tin.
# Location: Julian Thorne's private study waste bin
# Points to: Method of poisoning, Evelyn Reed
# Red herring: False
# ------------------------------------------------------------
# Clue #2
# Description: Forensic analysis of Julian Thorne's highly secured personal tablet reveals an encrypted data file. The filename contains a string of numbers that, when partially decoded, hints at a large, unrecorded financial transaction and a family name 'Reed'.
# Location: Julian Thorne's personal tablet
# Points to: Evelyn Reed's motive, Evelyn Reed's brother
# Red herring: False
# ------------------------------------------------------------
# Clue #3
# Description: A chef's assistant confirms seeing Evelyn Reed in the main kitchen area around 10:15-10:30 PM, but notes she seemed unusually preoccupied and moved between stations more than necessary, suggesting she wasn't fully focused on the dessert preparation.
# Location: Grand Regent Hotel main kitchen
# Points to: Evelyn Reed's false alibi
# Red herring: False
# ------------------------------------------------------------
# Clue #4
# Description: Several gala staff members overheard a heated argument between Julian Thorne and his cousin, Marcus Thorne, earlier in the evening, concerning the 'direction of the foundation' and 'irreconcilable differences' over funding allocations.
# Location: A secluded hallway near the ballroom
# Points to: Marcus Thorne, his motive (being replaced)
# Red herring: False
# ------------------------------------------------------------
# Clue #5
# Description: A diligent hotel maid reports seeing Lady Isabella Montgomery exiting the general vicinity of the private study wing, looking notably flustered and agitated, shortly after Julian Thorne began his keynote address.
# Location: Hallway near the private study wing
# Points to: Lady Isabella Montgomery, her motive (blackmail, affair)
# Red herring: False
# ------------------------------------------------------------
# Clue #6
# Description: A small, torn fragment of a receipt for specialized laboratory glassware and specific chemical reagents, dated several months prior, is discovered at the bottom of a rarely used recycling bin in the basement of Evelyn Reed's apartment building.
# Location: Evelyn Reed's apartment building's basement recycling bin
# Points to: Evelyn Reed, criminal means (synthesizing poison)
# Red herring: False
# ------------------------------------------------------------
# Clue #7
# Description: The hotel's main security office reports a brief, unexplained 'glitch' in the CCTV system, specifically affecting a camera feed monitoring the hallway outside Thorne's private study, for approximately three minutes around 10:35 PM.
# Location: Hotel's security office/CCTV system
# Points to: Commander David Miller, security system vulnerability
# Red herring: False
# ------------------------------------------------------------
# Clue #8
# Description: Among Thorne's office paperwork in his study, a discreet, typewritten memo from Evelyn Reed is found, dated weeks prior, reminding him to restock his 'specific 'Evergreen Essence' lozenges, noting their bespoke formulation made them hard to find'.
# Location: Julian Thorne's private study
# Points to: Evelyn Reed, specific knowledge of Thorne's habits, method of poisoning
# Red herring: False
# ------------------------------------------------------------

# %%
def build_countdown_text(step_index: int, total_steps: int = 15) -> str:
    remaining = total_steps - step_index + 1

    if remaining > 10:
        urgency = "low but rising"
    elif remaining > 5:
        urgency = "moderate and increasingly serious"
    elif remaining > 2:
        urgency = "high"
    else:
        urgency = "extreme"

    return (
        f"COUNTDOWN: The detective has only {remaining} major investigative moves remaining "
        f"before the case reaches a point of no return. Urgency level: {urgency}."
    )

# %%
def build_plot_context(world: StoryWorld) -> str:
    if not world.crime_details:
        raise ValueError("world.crime_details is missing")

    crime = world.crime_details

    detective = next((c for c in world.characters if c.role == "detective"), None)
    if detective is None:
        raise ValueError("No detective found in world.characters")

    suspects = [c for c in world.characters if c.role in ("suspect", "criminal")]
    discovered_clues = world.discovered_clues()

    payload = {
        "crime_details": {
            "crime_type": crime.crime_type,
            "victim": crime.victim,
            "location": crime.location,
            "time_of_crime": crime.time_of_crime,
            "method": crime.method,
            "backstory_summary": crime.backstory_summary,
        },
        "detective": {
            "name": detective.name,
            "description": detective.description,
            "motive": detective.motive,
        },
        "active_suspects": [
            {
                "name": c.name,
                "role": c.role,
                "description": c.description,
                "means": c.means,
                "motive": c.motive,
                "opportunity": c.opportunity,
                "alibi": c.alibi,
                "alibi_is_lie": c.alibi_is_lie,
                "eliminated": c.eliminated,
            }
            for c in suspects if not c.eliminated
        ],
        "discovered_clues": [
            {
                "clue_id": cl.clue_id,
                "description": cl.description,
                "location": cl.location,
                "is_red_herring": cl.is_red_herring,
                "points_to": cl.points_to,
            }
            for cl in discovered_clues
        ],
        "undiscovered_clues": [
            {
                "clue_id": cl.clue_id,
                "description": cl.description,
                "location": cl.location,
                "is_red_herring": cl.is_red_herring,
                "points_to": cl.points_to,
            }
            for cl in world.clues if not cl.discovered
        ],
        "prior_plot_points": [
            {
                "index": p.index,
                "title": p.title,
                "description": p.description,
                "action_taken": p.action_taken,
                "outcome": p.outcome,
                "obstacle": p.obstacle,
                "suspense_score": p.suspense_score,
                "characters_involved": p.characters_involved,
                "clues_revealed": p.clues_revealed,
                "clues_used": p.clues_used,
            }
            for p in world.plot_points
        ]
    }

    return json.dumps(payload, indent=2)

# %%
def build_next_plot_point_prompt(world: StoryWorld, step_index: int, total_steps: int = 15) -> str:
    detective = next((c for c in world.characters if c.role == "detective"), None)
    if detective is None:
        raise ValueError("No detective found")

    countdown_text = build_countdown_text(step_index, total_steps)

    detective_goal = (
        f"{detective.name} must identify the true criminal behind the "
        f"{world.crime_details.crime_type} of {world.crime_details.victim} before the final countdown expires."
    )

    deadline = getattr(world, "countdown_deadline", "")
    consequence = getattr(world, "countdown_consequence", "")
    
    countdown_block = f"""
    DEADLINE:
    {deadline}
    
    CONSEQUENCE:
    {consequence}
    """

    return f"""
You are the suspense-planning controller for a crime mystery.

Your job is to generate exactly ONE next plot point in a 15-step detective story.

This story must use suspense generation:
1. The audience cares about the detective and the victim.
2. The detective has a concrete goal.
3. Failure has dire consequences.
4. Each new plot point makes success harder, more urgent, or less likely.
5. Suspense comes from narrowing options, increasing uncertainty, and reducing chances to avert failure.
6. Do NOT resolve the full case early.

Detective goal:
{detective_goal}

{countdown_block}

{countdown_text}

Current story state:
{build_plot_context(world)}

Rules for this next plot point:
- This is plot point #{step_index} of {total_steps}.
- The detective must take a concrete action.
- That action must produce a meaningful outcome, but not fully solve the case unless this is the final plot point.
- Introduce or intensify an obstacle.
- Suspense must generally rise over time.
- Reveal 0, 1, or 2 clues at this step.
- Use already discovered clues when relevant.
- A clue can be revealed only once.
- You may eliminate at most one suspect in a single step.
- The detective should not identify the real criminal before plot point 13.
- Plot points 13-15 should feel like endgame escalation.
- A false lead, contradiction, missing evidence, time pressure, or witness unreliability can be used as obstacles.
- Keep the action grounded in crime solving, not action-movie spectacle.

Return ONLY valid JSON with exactly this structure:
{{
  "index": {step_index},
  "title": "...",
  "description": "...",
  "action_taken": "...",
  "outcome": "...",
  "obstacle": "...",
  "suspense_score": 0.0,
  "characters_involved": ["..."],
  "clues_revealed": [1, 2],
  "clues_used": [1, 2],
  "suspect_eliminated": "Name or empty string",
  "countdown_note": "How the countdown pressure changed in this step"
}}

Constraints on suspense_score:
- It should usually increase over time.
- Early steps: around 0.25 to 0.45
- Middle steps: around 0.45 to 0.75
- Late steps: around 0.75 to 0.98

Return JSON only.
""".strip()

# %%
def apply_plot_point_to_world(world: StoryWorld, data: dict) -> PlotPoint:
    plot_point = PlotPoint(
        index=data["index"],
        title=data["title"],
        description=data["description"],
        action_taken=data["action_taken"],
        outcome=data["outcome"],
        obstacle=data["obstacle"],
        suspense_score=float(data["suspense_score"]),
        characters_involved=data.get("characters_involved", []),
        clues_revealed=data.get("clues_revealed", []),
        clues_used=data.get("clues_used", [])
    )

    # Mark newly revealed clues as discovered
    for clue_id in plot_point.clues_revealed:
        clue = world.get_clue(clue_id)
        if clue:
            clue.discovered = True
            clue.revealed_in_plot_point = plot_point.index

    # Eliminate suspect if applicable
    suspect_name = data.get("suspect_eliminated", "").strip()
    if suspect_name:
        character = world.get_character(suspect_name)
        if character and character.role in ("suspect", "criminal") and not character.is_criminal:
            character.eliminated = True
            character.notes.append(f"Eliminated in plot point {plot_point.index}")

    world.plot_points.append(plot_point)
    return plot_point

# %%
def build_plot_point_validation_prompt(world: StoryWorld, candidate: dict, total_steps: int = 15) -> str:
    return f"""
You are validating one plot point in a suspenseful detective story.

Current story state:
{build_plot_context(world)}

Candidate plot point:
{json.dumps(candidate, indent=2)}

Check:
1. Is the detective taking a concrete investigative action?
2. Does the plot point increase or maintain suspense appropriately?
3. Does it avoid solving the whole case too early?
4. Are clue reveals valid and non-contradictory?
5. Is any suspect elimination justified?
6. Is the obstacle meaningful?
7. Is this consistent with a countdown-based suspense structure?

Return ONLY valid JSON:
{{
  "is_valid": true,
  "issues": ["..."],
  "suggested_fixes": ["..."]
}}
""".strip()


def validate_plot_point(world: StoryWorld, candidate: dict) -> dict:
    raw = ask_llm(build_plot_point_validation_prompt(world, candidate))
    return extract_json(raw)

# %%
def generate_next_plot_point(world: StoryWorld, step_index: int, total_steps: int = 15, max_attempts: int = 3) -> PlotPoint:
    last_candidate = None

    for attempt in range(max_attempts):
        prompt = build_next_plot_point_prompt(world, step_index, total_steps)
        raw = ask_llm(prompt)
        candidate = extract_json(raw)
        last_candidate = candidate

        validation = validate_plot_point(world, candidate)

        if validation.get("is_valid", False):
            return apply_plot_point_to_world(world, candidate)

    # fallback: use the last candidate even if imperfect
    if last_candidate is None:
        raise ValueError(f"Failed to generate plot point {step_index}")

    return apply_plot_point_to_world(world, last_candidate)

# %%
def generate_plot_points(world: StoryWorld, total_steps: int = 15) -> StoryWorld:
    if not world.crime_details:
        raise ValueError("Generate crime details first.")
    if not world.characters:
        raise ValueError("Generate characters first.")
    if not world.clues:
        raise ValueError("Generate clues first.")

    world.plot_points = []

    for step_index in range(1, total_steps + 1):
        print(f"Generating plot point {step_index}/{total_steps}...")
        plot_point = generate_next_plot_point(world, step_index, total_steps)
        print(f"  -> {plot_point.title} (suspense={plot_point.suspense_score:.2f})")

    return world

# %%
def build_full_plot_validation_prompt(world: StoryWorld) -> str:
    payload = {
        "crime_type": world.crime_details.crime_type if world.crime_details else "",
        "victim": world.crime_details.victim if world.crime_details else "",
        "plot_points": [
            {
                "index": p.index,
                "title": p.title,
                "description": p.description,
                "action_taken": p.action_taken,
                "outcome": p.outcome,
                "obstacle": p.obstacle,
                "suspense_score": p.suspense_score,
                "characters_involved": p.characters_involved,
                "clues_revealed": p.clues_revealed,
                "clues_used": p.clues_used,
            }
            for p in world.plot_points
        ],
        "remaining_active_suspects": [c.name for c in world.active_suspects()],
        "discovered_clues": [cl.clue_id for cl in world.discovered_clues()]
    }

    return f"""
You are validating the full suspense arc of a 15-point detective mystery.

Data:
{json.dumps(payload, indent=2)}

Check:
1. Do the 15 plot points form a coherent progression?
2. Does suspense generally rise?
3. Does the countdown mechanism feel meaningful?
4. Is the case not solved too early?
5. Are the final 3 plot points endgame escalation?
6. Are clue reveals paced well?
7. Are there any repetitive or filler beats?

Return ONLY valid JSON:
{{
  "is_valid": true,
  "issues": ["..."],
  "suggested_fixes": ["..."],
  "arc_score": 0.0
}}
""".strip()


def validate_full_plot_arc(world: StoryWorld) -> dict:
    raw = ask_llm(build_full_plot_validation_prompt(world))
    return extract_json(raw)

# %%
def print_plot_points(world: StoryWorld):
    print("\nPLOT POINTS")
    print("=" * 80)

    for p in sorted(world.plot_points, key=lambda x: x.index):
        print(f"[{p.index}] {p.title}")
        print(f"Description: {p.description}")
        print(f"Action Taken: {p.action_taken}")
        print(f"Outcome: {p.outcome}")
        print(f"Obstacle: {p.obstacle}")
        print(f"Suspense Score: {p.suspense_score:.2f}")
        print(f"Characters Involved: {p.characters_involved}")
        print(f"Clues Revealed: {p.clues_revealed}")
        print(f"Clues Used: {p.clues_used}")
        print("-" * 80)

# %%
world = generate_plot_points(world, total_steps=15)
print_plot_points(world)

arc_validation = validate_full_plot_arc(world)
print("\nFULL ARC VALIDATION")
pprint(arc_validation)
# Out:
# Generating plot point 1/15...
#   -> First Impressions and Microscopic Anomaly (suspense=0.35)
# Generating plot point 2/15...
#   -> Conflicting Alibis and Shifting Shadows (suspense=0.40)
# Generating plot point 3/15...
#   -> Forensic Confirmation and a Scientific Riddle (suspense=0.44)
# Generating plot point 4/15...
#   -> A Scientific Past and a Lingering Scent (suspense=0.51)
# Generating plot point 5/15...
#   -> A Hidden Cache and a Fresh Suspect (suspense=0.58)
# Generating plot point 6/15...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[86], line 1
# ----> 1 world = generate_plot_points(world, total_steps=15)
#       2 print_plot_points(world)
#       4 arc_validation = validate_full_plot_arc(world)
#
# Cell In[38], line 13, in generate_plot_points(world, total_steps)
#      11 for step_index in range(1, total_steps + 1):
#      12     print(f"Generating plot point {step_index}/{total_steps}...")
# ---> 13     plot_point = generate_next_plot_point(world, step_index, total_steps)
#      14     print(f"  -> {plot_point.title} (suspense={plot_point.suspense_score:.2f})")
#      16 return world
#
# Cell In[82], line 6, in generate_next_plot_point(world, step_index, total_steps, max_attempts)
#       4 for attempt in range(max_attempts):
#       5     prompt = build_next_plot_point_prompt(world, step_index, total_steps)
# ----> 6     raw = ask_llm(prompt)
#       7     candidate = extract_json(raw)
#       8     last_candidate = candidate
#
# Cell In[9], line 2, in ask_llm(prompt)
#       1 def ask_llm(prompt: str):
# ----> 2     response = client.models.generate_content(
#       3         model=MODEL,
#       4         contents=prompt
#       5     )
#       6     return response.text.strip()
#
# File /opt/anaconda3/lib/python3.13/site-packages/google/genai/models.py:5864, in Models.generate_content(self, model, contents, config)
#    5862 while remaining_remote_calls_afc > 0:
#    5863   i += 1
# -> 5864   response = self._generate_content(
#    5865       model=model, contents=contents, config=parsed_config
#    5866   )
#    5868   function_map = _extra_utils.get_function_map(parsed_config)
#    5869   if not function_map:
#
# File /opt/anaconda3/lib/python3.13/site-packages/google/genai/models.py:4526, in Models._generate_content(self, model, contents, config)
#    4523 request_dict = _common.convert_to_dict(request_dict)
#    4524 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4526 response = self._api_client.request(
#    4527     'post', path, request_dict, http_options
#    4528 )
#    4530 if config is not None and getattr(
#    4531     config, 'should_return_http_response', None
#    4532 ):
#    4533   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File /opt/anaconda3/lib/python3.13/site-packages/google/genai/_api_client.py:1402, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1392 def request(
#    1393     self,
#    1394     http_method: str,
#    (...)
#    1397     http_options: Optional[HttpOptionsOrDict] = None,
#    1398 ) -> SdkHttpResponse:
#    1399   http_request = self._build_request(
#    1400       http_method, path, request_dict, http_options
#    1401   )
# -> 1402   response = self._request(http_request, http_options, stream=False)
#    1403   response_body = (
#    1404       response.response_stream[0] if response.response_stream else ''
#    1405   )
#    1406   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File /opt/anaconda3/lib/python3.13/site-packages/google/genai/_api_client.py:1238, in BaseApiClient._request(self, http_request, http_options, stream)
#    1235     retry = tenacity.Retrying(**retry_kwargs)
#    1236     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1238 return self._retry(self._request_once, http_request, stream)
#
# File /opt/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:475, in Retrying.__call__(self, fn, *args, **kwargs)
#     473 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474 while True:
# --> 475     do = self.iter(retry_state=retry_state)
#     476     if isinstance(do, DoAttempt):
#     477         try:
#
# File /opt/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:376, in BaseRetrying.iter(self, retry_state)
#     374 result = None
#     375 for action in self.iter_state.actions:
# --> 376     result = action(retry_state)
#     377 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:418, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     416 retry_exc = self.retry_error_cls(fut)
#     417 if self.reraise:
# --> 418     raise retry_exc.reraise()
#     419 raise retry_exc from fut.exception()
#
# File /opt/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:185, in RetryError.reraise(self)
#     183 def reraise(self) -> t.NoReturn:
#     184     if self.last_attempt.failed:
# --> 185         raise self.last_attempt.result()
#     186     raise self
#
# File /opt/anaconda3/lib/python3.13/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /opt/anaconda3/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /opt/anaconda3/lib/python3.13/site-packages/tenacity/__init__.py:478, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 if isinstance(do, DoAttempt):
#     477     try:
# --> 478         result = fn(*args, **kwargs)
#     479     except BaseException:  # noqa: B902
#     480         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File /opt/anaconda3/lib/python3.13/site-packages/google/genai/_api_client.py:1215, in BaseApiClient._request_once(self, http_request, stream)
#    1207 else:
#    1208   response = self._httpx_client.request(
#    1209       method=http_request.method,
#    1210       url=http_request.url,
#    (...)
#    1213       timeout=http_request.timeout,
#    1214   )
# -> 1215   errors.APIError.raise_for_response(response)
#    1216   return HttpResponse(
#    1217       response.headers, response if stream else [response.text]
#    1218   )
#
# File /opt/anaconda3/lib/python3.13/site-packages/google/genai/errors.py:134, in APIError.raise_for_response(cls, response)
#     131 else:
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File /opt/anaconda3/lib/python3.13/site-packages/google/genai/errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     145 """Raises an appropriate APIError subclass based on the status code.
#     146
#     147 Args:
#    (...)
#     156   APIError: For other error status codes.
#     157 """
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#     161   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash\nPlease retry in 51.413814237s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '51s'}]}}

# %% [markdown]
# ## What Remains To Be Built
#
# ### Section 2 — Story Detail Construction (David)
# Populate the `StoryWorld` dataclasses using an iterative LLM prompting loop.
#
# **Phase 1 — Crime backstory** (`CrimeDetails`)
# - Prompt the LLM to generate the hidden crime: victim, location, time, method, criminal, motive, means, and hidden evidence.
# - Store result in `world.crime_details`.
#
# **Phase 2 — Characters & clues** (`Character`, `Clue`)
# - Prompt for: one detective, one criminal (posing as suspect), and 3 innocent suspects — each with explicit means, motive, opportunity, and alibi.
# - At least one suspect should have a false alibi (for an unrelated secret).
# - Prompt for 6 clues: 4 genuine (point to criminal), 2 red herrings (mislead to innocent suspect).
# - Append all to `world.characters` and `world.clues`.
#
# **Phase 3 — Iterative suspense loop** (`PlotPoint`) — *the core of the system*
# - Run 16 iterations. Each iteration makes two sequential LLM calls:
#   - **Stage A**: given story state so far, propose the detective's next concrete action.
#   - **Stage B**: introduce an obstacle that makes success feel less likely (suspense rises).
# - Pass `world.summary_so_far()` as context in every prompt so the LLM stays consistent.
# - Assign a `suspense_score` that rises monotonically from ~0.15 → ~0.98 across all 16 beats.
# - Mark clues as `discovered=True` when they are revealed in a plot point.
# - Append each result as a `PlotPoint` to `world.plot_points`.
#
#
# ---
#
# ### Section 3 — Story Fine-Tuning (Chaeyoung)
# Validate and assemble the raw materials into a final readable story.
#
# - **Validation**: assert `len(world.plot_points) >= 15`, at least one criminal, one detective, one red herring, one false alibi, and monotonically increasing suspense scores.
# - **Consistency check**: prompt the LLM to review all characters, clues, and plot point outcomes for contradictions.
# - **Narrative assembly**: pass all 16 raw `PlotPoint.description` fields to the LLM and ask it to rewrite them as a single fluent prose story. Store in `world.final_narrative`.
# - **Hidden story reveal**: separately print `world.crime_details.backstory_summary` — this is the second story the detective reconstructs at the end.

# %%
def validate_story_structure(world: StoryWorld) -> dict:
    issues = []

    # Plot points
    if len(world.plot_points) < 15:
        issues.append(f"Expected at least 15 plot points, found {len(world.plot_points)}.")

    # Character role checks
    detectives = [c for c in world.characters if c.role == "detective"]
    criminals = [c for c in world.characters if c.is_criminal or c.role == "criminal"]

    if len(detectives) < 1:
        issues.append("No detective found.")
    if len(criminals) < 1:
        issues.append("No criminal found.")

    # Red herring clue
    red_herrings = [cl for cl in world.clues if cl.is_red_herring]
    if len(red_herrings) < 1:
        issues.append("No red herring clue found.")

    # False alibi
    false_alibis = [c for c in world.characters if c.alibi_is_lie]
    if len(false_alibis) < 1:
        issues.append("No false alibi found.")

    # Monotonic suspense
    suspense_scores = [p.suspense_score for p in sorted(world.plot_points, key=lambda x: x.index)]
    for i in range(1, len(suspense_scores)):
        if suspense_scores[i] < suspense_scores[i - 1]:
            issues.append(
                f"Suspense score decreased from plot point {i} to {i+1}: "
                f"{suspense_scores[i-1]} -> {suspense_scores[i]}"
            )
            break

    return {
        "is_valid": len(issues) == 0,
        "issues": issues
    }

# %%
structure_report = validate_story_structure(world)
print("STRUCTURE VALIDATION")
pprint(structure_report)
# Out:
# STRUCTURE VALIDATION
# {'is_valid': True, 'issues': []}

# %%
def build_consistency_check_prompt(world: StoryWorld) -> str:
    payload = {
        "crime_details": {
            "crime_type": world.crime_details.crime_type if world.crime_details else "",
            "victim": world.crime_details.victim if world.crime_details else "",
            "location": world.crime_details.location if world.crime_details else "",
            "time_of_crime": world.crime_details.time_of_crime if world.crime_details else "",
            "method": world.crime_details.method if world.crime_details else "",
            "criminal_name": world.crime_details.criminal_name if world.crime_details else "",
            "criminal_motive": world.crime_details.criminal_motive if world.crime_details else "",
            "criminal_means": world.crime_details.criminal_means if world.crime_details else "",
            "backstory_summary": world.crime_details.backstory_summary if world.crime_details else "",
        },
        "characters": [
            {
                "name": c.name,
                "role": c.role,
                "description": c.description,
                "means": c.means,
                "motive": c.motive,
                "opportunity": c.opportunity,
                "alibi": c.alibi,
                "alibi_is_lie": c.alibi_is_lie,
                "is_criminal": c.is_criminal,
                "eliminated": c.eliminated,
                "notes": c.notes,
            }
            for c in world.characters
        ],
        "clues": [
            {
                "clue_id": cl.clue_id,
                "description": cl.description,
                "location": cl.location,
                "discovered": cl.discovered,
                "is_red_herring": cl.is_red_herring,
                "points_to": cl.points_to,
                "revealed_in_plot_point": cl.revealed_in_plot_point,
            }
            for cl in world.clues
        ],
        "plot_points": [
            {
                "index": p.index,
                "title": p.title,
                "description": p.description,
                "action_taken": p.action_taken,
                "outcome": p.outcome,
                "obstacle": p.obstacle,
                "suspense_score": p.suspense_score,
                "characters_involved": p.characters_involved,
                "clues_revealed": p.clues_revealed,
                "clues_used": p.clues_used,
            }
            for p in sorted(world.plot_points, key=lambda x: x.index)
        ]
    }

    return f"""
You are checking a crime mystery story plan for contradictions and logic problems.

Review the following story materials:
{json.dumps(payload, indent=2)}

Check for:
1. Character contradictions
2. Clue contradictions
3. Impossible timeline issues
4. Plot point outcomes that conflict with later events
5. Eliminated suspects acting as if still viable later without explanation
6. Clues that appear without being revealed
7. Any mismatch between the hidden crime and the detective's reconstructed story
8. Whether the final solution points to the real criminal

Return ONLY valid JSON in exactly this format:
{{
  "is_consistent": true,
  "issues": [
    "...",
    "..."
  ],
  "summary": "Brief overall judgment."
}}
""".strip()

# %%
def run_consistency_check(world: StoryWorld) -> dict:
    raw = ask_llm(build_consistency_check_prompt(world))
    return extract_json(raw)

# %%
consistency_report = run_consistency_check(world)
print("CONSISTENCY CHECK")
pprint(consistency_report)
# Out:
# CONSISTENCY CHECK
# {'is_consistent': False,
#  'issues': ["Clue 4 ('A drafted letter on the judge’s desk...') is marked with "
#             "'revealed_in_plot_point: 1', implying it should be introduced in "
#             "Plot Point 1. However, Plot Point 1's 'clues_revealed' array ([2, "
#             '8]) does not include Clue 4. This creates a discrepancy, as Clara '
#             "Vance's motive is never formally introduced via this specific "
#             'clue within the plot points provided.',
#             "Several critical clues are referenced as being 'revealed' in plot "
#             "points (via 'clues_revealed' arrays and described in 'outcome' "
#             "fields) but are not actually defined in the main 'clues' array. "
#             'These missing definitions are: Clue ID 9 (industrial wire '
#             'stripper striation patterns, revealed in Plot Point 7), Clue ID '
#             '10 (synthetic fiber from work gloves, revealed in Plot Point 12), '
#             'Clue ID 11 (escape map, revealed in Plot Point 13), Clue ID 12 '
#             '(abandoned escape vehicle, revealed in Plot Point 13), Clue ID 13 '
#             '(unscheduled private charter plane, revealed in Plot Point 14), '
#             'and Clue ID 14 (foreign passport under new identity, revealed in '
#             "Plot Point 14). This makes the story's progression reliant on "
#             'undefined elements.',
#             "Robert 'Bobby' Miller is effectively eliminated as a suspect for "
#             'the murder method in Plot Point 8, as his equipment is confirmed '
#             'not to include the specialized wire stripper capable of producing '
#             "the identified striations. However, his 'eliminated' status in "
#             "the 'characters' array remains 'false', which is a minor "
#             'inconsistency with the plot progression.'],
#  'summary': 'The story plan presents a compelling narrative with a clear '
#             'criminal, motive, and a logical investigative path for the '
#             'detective. However, there are significant inconsistencies in the '
#             'handling of clues, with several pivotal clues being referenced '
#             'and revealed within the plot points without corresponding '
#             "definitions in the main 'clues' array. Additionally, one existing "
#             "clue's revelation is mismatched with its designated plot point, "
#             'and a suspect who is functionally eliminated is not marked as '
#             'such. These issues impact the overall consistency and '
#             'completeness of the provided materials.'}

# %%
def build_narrative_assembly_prompt(world: StoryWorld) -> str:
    detective = next((c for c in world.characters if c.role == "detective"), None)

    plot_descriptions = [
        {
            "index": p.index,
            "title": p.title,
            "description": p.description,
            "action_taken": p.action_taken,
            "outcome": p.outcome,
            "obstacle": p.obstacle
        }
        for p in sorted(world.plot_points, key=lambda x: x.index)
    ]

    payload = {
        "detective_name": detective.name if detective else "The detective",
        "crime_type": world.crime_details.crime_type if world.crime_details else "",
        "victim": world.crime_details.victim if world.crime_details else "",
        "location": world.crime_details.location if world.crime_details else "",
        "countdown_deadline": world.countdown_deadline if world.countdown_deadline else "",
        "countdown_consequence": world.countdown_consequence if world.countdown_consequence else "",
        "plot_points": plot_descriptions
    }

    return f"""
You are assembling a suspenseful detective story into fluent prose.

Use the following raw plot-point materials:
{json.dumps(payload, indent=2)}

Task:
- Rewrite these plot points as one continuous, readable short story in prose.
- Preserve the order of events.
- Keep the story suspenseful and coherent.
- Emphasize investigation, uncertainty, red herrings, and mounting countdown pressure.
- Do not write in bullet points.
- Do not mention "plot point" explicitly.
- The ending should show the detective arriving at the truth.
- Make it read like a polished mystery synopsis or short story retelling.

Output only the final prose story.
""".strip()

# %%
def assemble_final_narrative(world: StoryWorld) -> str:
    if len(world.plot_points) < 15:
        raise ValueError("Need at least 15 plot points before assembling final narrative.")

    raw = ask_llm(build_narrative_assembly_prompt(world))
    world.final_narrative = raw.strip()
    return world.final_narrative

# %%
final_story = assemble_final_narrative(world)
print(world.final_narrative)
# Out:
# The hush of Sterling Manor’s opulent library hung heavy with the recent scent of death as Inspector Silas Vane stepped across its threshold. Humming a subtle classical melody, a tune that always accompanied his most precise forensic examinations, his gaze immediately fixed on the mahogany reading desk and the tampered brass lamp beside it. The initial assessment confirmed an ingenious and lethal rewiring, the kind that spoke of a perpetrator with considerable technical skill. But as his team meticulously swept the scene, the waters quickly muddied. Near the library entrance, a professional-grade digital multimeter, bearing the distinct etching 'Miller & Sons,' was discovered. Simultaneously, several crumpled 'Final Notice' casino debt letters, addressed to Julian Sterling, the judge's nephew, were pulled from the wastebasket. Vane felt the first pang of uncertainty; two compelling, yet disparate, motives had just emerged, forcing him to immediately consider two distinct profiles for the killer.
#
# His humming shifted to a minor key as Vane turned his attention from the immediate scene to the broader electrical infrastructure of the manor. The sophisticated nature of the electrocution, hinting at expert manipulation, demanded an investigation into how the manor's power system was involved, especially given the scheduled maintenance. Tracing wiring pathways, he meticulously examined the external circuit breaker box. There, almost hidden on an inner hinge, he discovered a small scrap of high-grade black electrical tape. This wasn't household tape; it suggested professional or industrial application. The clue, though strong, complicated matters further. While Robert Miller, the electrical contractor, had legitimate access and professional tools, the scheduled power maintenance meant others—Marcus Thorne, the quiet gardener with industrial training, and Beatrice Gable, the housekeeper performing blackout checks—had plausible reasons to be near the circuit box. The pool of suspects with access had broadened, making the tape less decisive, increasing Vane’s uncertainty.
#
# A tense, unresolved chord hummed in Vane's mind. The sophisticated electrical tampering and the high-grade electrical tape screamed of specialized technical skill. He decided to scrutinize the alibis of those with such expertise or unusual access during the maintenance window, starting with Marcus Thorne. The gardener's claim of securing greenhouse panels against an impending windstorm now felt strangely out of tune with the meticulous crime. Vane meticulously cross-referenced Thorne's alibi with the manor's internal weather station console and external meteorological reports. The discovery was stark: the night of the murder had been completely calm, with no recorded wind gusts. Marcus Thorne's alibi was an unequivocal fabrication. Thorne, the unassuming gardener, was a calculated liar. But the stark contrast between his public persona and the technical prowess required for the murder created a new hurdle: was he merely covering for someone, or did he possess a hidden depth Vane had yet to uncover? The 'why' behind his lie remained as obscure as the 'how' of his direct involvement, twisting the path forward into a convoluted maze.
#
# Vane's melody turned distinctly melancholic. Thorne's shattered alibi resonated with the sophisticated electrical tampering; the calculated deception demanded a deeper look. He obtained a search warrant and conducted a thorough examination of the gardener's shed. Tucked beneath old seed catalogs, he discovered a worn leather-bound ledger. On the page corresponding to the murder date, the initials 'E.T.' were circled in faded red ink, alongside the stark, singular word: 'Justice.' The cryptic nature of the ledger pointed to a profound, long-standing motive, but Vane had no immediate knowledge of 'E.T.' or their connection to Judge Sterling. Uncovering this link would require extensive archival research, a time-consuming and arduous task that could lead down numerous rabbit holes, consuming precious investigative time. Thorne became a more complex, less predictable suspect, and the urgency to understand his true identity mounted.
#
# A grim, somber tune replaced Vane's usual melodies as he plunged into the labyrinthine archives of Judge Sterling's past. Sifting through decades of case files, he searched for the ghost of a name, a historical injustice. After extensive research, the tragic case of Elias Thorne emerged: a man wrongfully convicted decades ago due to suppressed evidence, a decision personally overseen by then-prosecutor Arthur Sterling. It revealed a profound injustice, a powerful, deeply personal motive for vengeance, explaining the 'Justice' entry in Marcus Thorne's ledger. Yet, a crucial piece was missing: official records of Elias Thorne's family were either missing or redacted, making no mention of a son named Marcus. Vane now faced the challenge of proving that Marcus was indeed Elias's son and the orchestrator of this intricate plot. The uncertainty increased the urgency to find a direct familial connection.
#
# His hum-tune grew grave and determined. Vane deepened his investigation into Marcus. The missing official link demanded a more personal approach. He conducted a covert but thorough search of Marcus Thorne's private living quarters on the estate. Within Thorne's spartan room, Vane discovered a faded, cherished photograph of a younger Marcus standing proudly beside an older man, clearly Elias Thorne, with a poignant, handwritten inscription: 'My son, Marcus, and I – before they took everything.' More critically, tucked away inside a bag of damp mulch, Vane unearthed a pair of heavy-duty, rubber-soled work boots, their treads glinting subtly with microscopic copper shavings. The evidence solidified Marcus Thorne as the vengeful son, but it was still largely circumstantial without direct eyewitness testimony or a confession proving he tampered with *that specific lamp*. A premature arrest could allow Thorne to destroy further clues or escape. Delaying gave Thorne time to react to the increasing scrutiny. Vane's options were tightening.
#
# Humming a complex, analytical tune, Vane dispatched the meticulously tampered brass lamp to the Met's forensic lab. The 'unusually loose dial' and the sophistication of the electrocution demanded a deep dive. The forensic report confirmed expert rewiring. Microscopic examination revealed distinct, precise striation patterns on the exposed copper wiring, unequivocally consistent with a highly specialized, industrial-grade wire stripper – a tool far beyond standard household varieties. Yet, the forensic team was unable to definitively identify the exact make or model of the specialized tool. This forced Vane into a painstaking, laborious search for a specific, yet potentially generic or unbranded, industrial tool, consuming vital investigative time and preventing a definitive link to Marcus Thorne.
#
# A frantic, racing melody now replaced Vane's previous tunes. He intensified his hunt for the industrial-grade wire stripper, ordering an immediate, focused inventory of tools belonging to both Marcus Thorne and Robert Miller. From Thorne's supposedly secure garden shed, the estate manager confirmed that a high-end, heavy-duty industrial wire stripper, consistent with the lab's general description, was conspicuously missing. The shed showed signs of a recent, clumsy attempt at forced entry where only that tool seemed to have been taken. Simultaneously, Robert Miller's comprehensive equipment log confirmed he owned no tool that could have produced the precise striations on the victim's lamp. The disappearance of the incriminating stripper, coupled with the forced entry, signaled a critical escalation: Thorne was not only the likely perpetrator but was actively aware of the investigation closing in. Vane had to act quickly to locate the disposed tool or apprehend Thorne before he could further evade capture or even attempt to silence potential witnesses. The window for a definitive link was rapidly narrowing.
#
# Driven by the urgency of the missing wire stripper, Vane coordinated an extensive search of the Sterling Manor grounds, targeting waste disposal areas and secluded spots known to Thorne. Near the manor's dilapidated, disused incinerator, the search team uncovered a small, freshly disturbed pit. Within it, amidst ash and charred debris, they found melted plastic fragments and small, deformed metal pieces. Forensic analysis quickly confirmed these were components consistent with the handle and structural frame of a high-grade industrial wire stripper, specifically the type capable of producing the striations noted on the lamp wiring. However, the crucial cutting blades, vital for a definitive forensic match, were conspicuously absent and unrecoverable from the wreckage. This discovery confirmed Thorne's desperate attempt to destroy the incriminating tool, but the complete absence of the blades created an immense obstacle. Without them, a definitive, irrefutable forensic match to the precise striation patterns on the lamp's wiring became impossible. Vane now faced the daunting challenge of proving Thorne's guilt based on strong circumstantial evidence of destruction, without the concrete link of the actual murder weapon. The countdown intensified, his options for an airtight case rapidly dwindling.
#
# A melody fraught with tension played in Vane's mind. He refused to be deterred by the incinerated wire stripper's missing blades. The copper shavings on the gardener's boots and the victim's tampered lamp called for a more fundamental comparison. Vane commissioned a specialized spectroscopic analysis, comparing the microscopic copper shavings recovered from Marcus Thorne's work boots against samples of the copper wiring found within the tampered brass lamp. The forensic report confirmed a near-perfect elemental and trace impurity match. The unique alloy composition, unusual for common household electronics, significantly strengthened the link to Thorne. Yet, the report carried a crucial caveat: the copper shavings were too minute and fragmented to bear any discernible tool marks or directional stress patterns. This prevented a definitive, undeniable link proving they were stripped from *that specific lamp* by *the missing tool*. This subtle ambiguity left a critical opening for a clever defense, demanding Vane find even more direct proof under intense time pressure.
#
# A relentless arpeggio now dominated Vane's thoughts as he plunged into Marcus Thorne's past, seeking definitive proof of his electrical expertise. The spectral match of copper shavings and the precise striations on the lamp's wiring cried out for a solid anchor against the shifting sands of circumstantial evidence. Vane's detailed investigation into Thorne's prior employment and educational records yielded official confirmation: years prior to becoming a gardener, Marcus Thorne had completed an advanced apprenticeship and earned certification in complex industrial electrical systems. This definitively established his means, demonstrating a level of expertise far beyond basic household wiring, directly aligning with the sophisticated nature of the murder. But this discovery profoundly altered Vane's perception of the man. Thorne was not merely an aggrieved son, but a highly skilled, patient, and dangerously intelligent individual who had meticulously crafted his revenge and carefully concealed his true capabilities. This realization heightened the urgency; Vane now faced a master manipulator, one who had already destroyed key evidence and whose next move was unpredictable. His options were narrowing, facing a more formidable and cunning adversary than he initially suspected.
#
# The arpeggio twisted into a desperate, frantic key. Vane refused to be thwarted. Even the most careful killer leaves behind some indelible trace. He ordered a painstaking, ultra-microscopic re-examination of the very heart of the murder weapon, focusing exclusively on non-electrical, foreign particulates, and fibers. The forensic team, after hours of meticulous work, discovered a single, almost invisible, synthetic fiber caught deep within the lamp's rewired internal switch. Microscopic analysis confirmed its unique blend, characteristic of the high-grade, industrially reinforced work gloves known to be favored and regularly used by Marcus Thorne for his more demanding tasks. This minute fiber provided the most direct and damning physical link yet, unequivocally tying Marcus Thorne to the precise act of tampering with the murder weapon.
#
# But the revelation coincided with a chilling development: Marcus Thorne was no longer on the estate. Having anticipated Vane's imminent capture or perhaps sensing the tightening noose, Thorne had vanished without a trace. The investigation transformed from a puzzle-solving exercise into an urgent manhunt, making Vane's success harder, the timeline dramatically shorter, and the risk of Thorne escaping justice permanently, or even retaliating, acutely real. The countdown for Vane had become a race against a ghost.
#
# A grim, determined march now thrummed through Vane. He mobilized every resource for the immediate manhunt. Thorne's sudden disappearance, coinciding with the glove fiber discovery, screamed of a premeditated escape. Vane directed his team to meticulously sweep the estate's perimeter and access points. Beneath a loose floorboard in Thorne's previously searched room, the team discovered a cleverly concealed, roughly drawn map of rural escape routes leading towards a remote, disused airfield miles from the manor. Near the airfield, local police later located a recently abandoned, unregistered vehicle, containing a small bag with several changes of clothing, some non-perishable food, and a short-wave radio. The discovery of Thorne's elaborate escape plan revealed a level of foresight and resources far beyond what Vane expected from a seemingly simple gardener. Thorne had been preparing for this escape for an extended period, perhaps with external assistance or an unexpectedly large sum of money. He had intended to flee immediately after the murder, anticipating detection. Vane’s window for capture was drastically reduced; Thorne aimed for complete off-grid disappearance, making tracking him exponentially more difficult. Vane’s options were narrowing to a desperate chase.
#
# A tense, desperate fugue now pulsed in Vane's mind. He recognized the chilling sophistication of Marcus Thorne's escape plan. With the immediate window for capture closing, Vane redirected all resources, focusing on his gut instinct that Thorne was aiming for a complete disappearance across borders. He mobilized all available law enforcement and intelligence assets to track and monitor small, private airfields, secluded ports, and known clandestine departure points within a 200-mile radius of the abandoned vehicle, prioritizing any unscheduled or unusual movements. Vane's team, acting on a tip regarding unusual flight patterns, successfully identified an unscheduled private charter plane that departed from a small, private airstrip near the coast shortly after Thorne's vehicle was discovered. Initial manifest information revealed a single passenger using a legitimate, but recently issued, foreign passport under an entirely new, unfamiliar identity. The discovery of a seemingly legitimate foreign passport and a successful flight out of the country under a new identity represented a monumental and potentially insurmountable obstacle. This confirmed Thorne's extraordinary foresight, his deep resources, and a professional level of planning far beyond Vane's initial assessment, suggesting potential external assistance. With Thorne now likely across international borders and operating under a verified, untraceable alias, the immediate chance for an arrest had vanished. Vane now faced the daunting challenge of pursuing a phantom through international legal labyrinths, with dwindling time and resources. Permanent escape felt alarmingly real.
#
# His hum-tune, usually a classical melody, was now a silent, grinding determination. With the countdown expired and Marcus Thorne a phantom across the seas, Inspector Vane's final, desperate move wasn't about a futile, immediate pursuit, but the preservation of truth. His goal, now more urgent than ever, was to forge an undeniable, irrefutable case against the escaped killer, ensuring that even if justice was delayed, it would not be denied or misdirected, and no other innocent soul would bear the blame. With unwavering focus and a deep sense of professional obligation, Vane meticulously consolidated every piece of forensic, circumstantial, and personal evidence against Marcus Thorne into a comprehensive, irrefutable dossier for the Crown Prosecution Service, preparing formal charges and an international extradition request. He successfully delivered an airtight case, detailing Marcus Thorne's true identity, his profound motive for vengeance, his sophisticated means, and the full weight of the circumstantial and forensic evidence. An international arrest warrant for Marcus Thorne was immediately issued, formally identifying him as the murderer of Judge Arthur Sterling. The true criminal was identified, and the truth officially established, preventing any wrongful accusations against other suspects.
#
# But the victory was bittersweet, overshadowed by the lingering freedom of the murderer. Marcus Thorne, now operating under a new, legitimate identity, had successfully fled across international borders. The ensuing international extradition process promised to be a protracted, arduous, and potentially futile legal battle, consuming immense resources and time. Vane was left with the unsettling certainty that justice, while identified and pursued, was far from served, and the architect of vengeance might forever remain a phantom beyond immediate reach.
